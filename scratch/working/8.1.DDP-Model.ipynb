# %% [markdown]
# # [모듈 2.0] 모델 빌딩하기 (No VPC 환경에서 실행하세요)

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.1.2'

# %% [markdown]
# # (1) Run the training locally

# %% [markdown]
# 본 스크립트는 모델 학습에 필요한 인자값(arguments)들을 사용합니다. 모델 학습에 필요한 인자값들은 아래와 같습니다.
#
# 1. `model_dir` - 로그와 체크 포인트를 저장하는 경로
# 2. `train, validation, eval` - TFRecord 데이터셋을 저장하는 경로
# 3. `epochs` - epoch 횟수
#
# 아래 명령어로 **<font color='red'>SageMaker 관련 API 호출 없이</font>** 로컬 노트북 인스턴스 환경에서 1 epoch만 학습해 봅니다. 참고로, MacBook Pro(15-inch, 2018) 2.6GHz Core i7 16GB 사양에서 2분 20초~2분 40초 소요됩니다.

# %%
# %%time
# !mkdir -p logs
# !python training_script/cifar10_keras_ddp_tf2.py --model_dir ./logs \
                                         --train data/train \
                                         --validation data/validation \
                                         --eval data/eval \
                                         --epochs 1
# !rm -rf logs
# Out:
# Step #0	Loss: 14.399995
# Step #10	Loss: 14.481102
# Step #20	Loss: 14.964404
# Step #30	Loss: 14.229256
# Step #40	Loss: 14.984791
# CPU times: user 114 ms, sys: 71 ms, total: 185 ms
# Wall time: 9.55 s

# %% [markdown]
# **<font color='blue'>본 스크립트는 SageMaker상의 notebook에서 구동하고 있지만, 여러분의 로컬 컴퓨터에서도 python과 jupyter notebook이 정상적으로 인스톨되어 있다면 동일하게 수행 가능합니다.</font>**

# %% [markdown]
# # (2) Use TensorFlow Script Mode

# %% [markdown]
# ### Test your script locally (just like on your laptop)
#
# 테스트를 위해 위와 동일한 명령(command)으로 새 스크립트를 실행하고, 예상대로 실행되는지 확인합니다. <br>
# SageMaker TensorFlow API 호출 시에 환경 변수들은 자동으로 넘겨기지만, 로컬 주피터 노트북에서 테스트 시에는 수동으로 환경 변수들을 지정해야 합니다. (아래 예제 코드를 참조해 주세요.)
#
# ```python
# %env SM_MODEL_DIR=./logs
# ```

# %%
# %%time
# !mkdir -p logs   

# Number of GPUs on this machine
# %env SM_NUM_GPUS=1
# Where to save the model
# %env SM_MODEL_DIR=./logs
# Where the training data is
# %env SM_CHANNEL_TRAIN=data/train
# Where the validation data is
# %env SM_CHANNEL_VALIDATION=data/validation
# Where the evaluation data is
# %env SM_CHANNEL_EVAL=data/eval

# !python training_script/cifar10_keras_sm_ddp_tf2.py --model_dir ./logs --epochs 1
# !rm -rf logs
# Out:
# env: SM_NUM_GPUS=1
# env: SM_MODEL_DIR=./logs
# env: SM_CHANNEL_TRAIN=data/train
# env: SM_CHANNEL_VALIDATION=data/validation
# env: SM_CHANNEL_EVAL=data/eval
# Step #0	Loss: 4.030188
# Step #10	Loss: 2.626105
# Step #20	Loss: 2.318017
# Step #30	Loss: 2.091323
# Step #40	Loss: 2.048301
# CPU times: user 157 ms, sys: 50.4 ms, total: 207 ms
# Wall time: 11.6 s

# %% [markdown]
# # (3) Use SageMaker local for local testing

# %%
import os
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()

# %% [markdown]
# `sagemaker.tensorflow` 클래스를 사용하여 SageMaker Python SDK의 Tensorflow Estimator 인스턴스를 생성합니다.
# 인자값으로 하이퍼파라메터와 다양한 설정들을 변경할 수 있습니다.
#
# 자세한 내용은 [documentation](https://sagemaker.readthedocs.io/en/stable/using_tf.html#training-with-tensorflow-estimator)을 확인하시기 바랍니다.

# %%
from sagemaker.tensorflow import TensorFlow
estimator = TensorFlow(base_job_name='cifar10',
                       entry_point='cifar10_keras_sm_ddp_tf2.py',
                       source_dir='training_script',
                       role=role,
                       framework_version='2.0.0',
                       py_version='py3',
                       script_mode=True,
                       hyperparameters={'epochs' : 1},
                       train_instance_count=1, 
                       train_instance_type='local')
# Out:
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# 학습을 수행할 3개의 채널과 데이터의 경로를 지정합니다. **로컬 모드로 수행하기 때문에 S3 경로 대신 노트북 인스턴스의 경로를 지정하시면 됩니다.**

# %%
# %%time
estimator.fit({'train': 'file://data/train',
               'validation': 'file://data/validation',
               'eval': 'file://data/eval'})
# Out:
# Building with native build. Learn about native build in Compose here: https://docs.docker.com/go/compose-native-build/
# Creating mbce57qndc-algo-1-yek3h ...
# Creating mbce57qndc-algo-1-yek3h ... done
# Attaching to mbce57qndc-algo-1-yek3h
# mbce57qndc-algo-1-yek3h | 2021-02-22 06:10:16,268 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# mbce57qndc-algo-1-yek3h | 2021-02-22 06:10:16,276 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# mbce57qndc-algo-1-yek3h | 2021-02-22 06:10:16,482 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# mbce57qndc-algo-1-yek3h | 2021-02-22 06:10:16,500 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# mbce57qndc-algo-1-yek3h | 2021-02-22 06:10:16,517 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# mbce57qndc-algo-1-yek3h | 2021-02-22 06:10:16,529 sagemaker-containers INFO     Invoking user script
# mbce57qndc-algo-1-yek3h |
# mbce57qndc-algo-1-yek3h | Training Env:
# mbce57qndc-algo-1-yek3h |
# mbce57qndc-algo-1-yek3h | {
# mbce57qndc-algo-1-yek3h |     "additional_framework_parameters": {},
# mbce57qndc-algo-1-yek3h |     "channel_input_dirs": {
# mbce57qndc-algo-1-yek3h |         "train": "/opt/ml/input/data/train",
# mbce57qndc-algo-1-yek3h |         "validation": "/opt/ml/input/data/validation",
# mbce57qndc-algo-1-yek3h |         "eval": "/opt/ml/input/data/eval"
# mbce57qndc-algo-1-yek3h |     },
# mbce57qndc-algo-1-yek3h |     "current_host": "algo-1-yek3h",
# mbce57qndc-algo-1-yek3h |     "framework_module": "sagemaker_tensorflow_container.training:main",
# mbce57qndc-algo-1-yek3h |     "hosts": [
# mbce57qndc-algo-1-yek3h |         "algo-1-yek3h"
# mbce57qndc-algo-1-yek3h |     ],
# mbce57qndc-algo-1-yek3h |     "hyperparameters": {
# mbce57qndc-algo-1-yek3h |         "epochs": 1,
# mbce57qndc-algo-1-yek3h |         "model_dir": "s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-09-30-963/model"
# mbce57qndc-algo-1-yek3h |     },
# mbce57qndc-algo-1-yek3h |     "input_config_dir": "/opt/ml/input/config",
# mbce57qndc-algo-1-yek3h |     "input_data_config": {
# mbce57qndc-algo-1-yek3h |         "train": {
# mbce57qndc-algo-1-yek3h |             "TrainingInputMode": "File"
# mbce57qndc-algo-1-yek3h |         },
# mbce57qndc-algo-1-yek3h |         "validation": {
# mbce57qndc-algo-1-yek3h |             "TrainingInputMode": "File"
# mbce57qndc-algo-1-yek3h |         },
# mbce57qndc-algo-1-yek3h |         "eval": {
# mbce57qndc-algo-1-yek3h |             "TrainingInputMode": "File"
# mbce57qndc-algo-1-yek3h |         }
# mbce57qndc-algo-1-yek3h |     },
# mbce57qndc-algo-1-yek3h |     "input_dir": "/opt/ml/input",
# mbce57qndc-algo-1-yek3h |     "is_master": true,
# mbce57qndc-algo-1-yek3h |     "job_name": "cifar10-2021-02-22-06-09-30-963",
# mbce57qndc-algo-1-yek3h |     "log_level": 20,
# mbce57qndc-algo-1-yek3h |     "master_hostname": "algo-1-yek3h",
# mbce57qndc-algo-1-yek3h |     "model_dir": "/opt/ml/model",
# mbce57qndc-algo-1-yek3h |     "module_dir": "s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-09-30-963/source/sourcedir.tar.gz",
# mbce57qndc-algo-1-yek3h |     "module_name": "cifar10_keras_sm_ddp_tf2",
# mbce57qndc-algo-1-yek3h |     "network_interface_name": "eth0",
# mbce57qndc-algo-1-yek3h |     "num_cpus": 32,
# mbce57qndc-algo-1-yek3h |     "num_gpus": 0,
# mbce57qndc-algo-1-yek3h |     "output_data_dir": "/opt/ml/output/data",
# mbce57qndc-algo-1-yek3h |     "output_dir": "/opt/ml/output",
# mbce57qndc-algo-1-yek3h |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# mbce57qndc-algo-1-yek3h |     "resource_config": {
# mbce57qndc-algo-1-yek3h |         "current_host": "algo-1-yek3h",
# mbce57qndc-algo-1-yek3h |         "hosts": [
# mbce57qndc-algo-1-yek3h |             "algo-1-yek3h"
# mbce57qndc-algo-1-yek3h |         ]
# mbce57qndc-algo-1-yek3h |     },
# mbce57qndc-algo-1-yek3h |     "user_entry_point": "cifar10_keras_sm_ddp_tf2.py"
# mbce57qndc-algo-1-yek3h | }
# mbce57qndc-algo-1-yek3h |
# mbce57qndc-algo-1-yek3h | Environment variables:
# mbce57qndc-algo-1-yek3h |
# mbce57qndc-algo-1-yek3h | SM_HOSTS=["algo-1-yek3h"]
# mbce57qndc-algo-1-yek3h | SM_NETWORK_INTERFACE_NAME=eth0
# mbce57qndc-algo-1-yek3h | SM_HPS={"epochs":1,"model_dir":"s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-09-30-963/model"}
# mbce57qndc-algo-1-yek3h | SM_USER_ENTRY_POINT=cifar10_keras_sm_ddp_tf2.py
# mbce57qndc-algo-1-yek3h | SM_FRAMEWORK_PARAMS={}
# mbce57qndc-algo-1-yek3h | SM_RESOURCE_CONFIG={"current_host":"algo-1-yek3h","hosts":["algo-1-yek3h"]}
# mbce57qndc-algo-1-yek3h | SM_INPUT_DATA_CONFIG={"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}}
# mbce57qndc-algo-1-yek3h | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# mbce57qndc-algo-1-yek3h | SM_CHANNELS=["eval","train","validation"]
# mbce57qndc-algo-1-yek3h | SM_CURRENT_HOST=algo-1-yek3h
# mbce57qndc-algo-1-yek3h | SM_MODULE_NAME=cifar10_keras_sm_ddp_tf2
# mbce57qndc-algo-1-yek3h | SM_LOG_LEVEL=20
# mbce57qndc-algo-1-yek3h | SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# mbce57qndc-algo-1-yek3h | SM_INPUT_DIR=/opt/ml/input
# mbce57qndc-algo-1-yek3h | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# mbce57qndc-algo-1-yek3h | SM_OUTPUT_DIR=/opt/ml/output
# mbce57qndc-algo-1-yek3h | SM_NUM_CPUS=32
# mbce57qndc-algo-1-yek3h | SM_NUM_GPUS=0
# mbce57qndc-algo-1-yek3h | SM_MODEL_DIR=/opt/ml/model
# mbce57qndc-algo-1-yek3h | SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-09-30-963/source/sourcedir.tar.gz
# mbce57qndc-algo-1-yek3h | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1-yek3h","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1-yek3h"],"hyperparameters":{"epochs":1,"model_dir":"s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-09-30-963/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"cifar10-2021-02-22-06-09-30-963","log_level":20,"master_hostname":"algo-1-yek3h","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-09-30-963/source/sourcedir.tar.gz","module_name":"cifar10_keras_sm_ddp_tf2","network_interface_name":"eth0","num_cpus":32,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-yek3h","hosts":["algo-1-yek3h"]},"user_entry_point":"cifar10_keras_sm_ddp_tf2.py"}
# mbce57qndc-algo-1-yek3h | SM_USER_ARGS=["--epochs","1","--model_dir","s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-09-30-963/model"]
# mbce57qndc-algo-1-yek3h | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# mbce57qndc-algo-1-yek3h | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# mbce57qndc-algo-1-yek3h | SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# mbce57qndc-algo-1-yek3h | SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# mbce57qndc-algo-1-yek3h | SM_HP_EPOCHS=1
# mbce57qndc-algo-1-yek3h | SM_HP_MODEL_DIR=s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-09-30-963/model
# mbce57qndc-algo-1-yek3h | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# mbce57qndc-algo-1-yek3h |
# mbce57qndc-algo-1-yek3h | Invoking script with the following command:
# mbce57qndc-algo-1-yek3h |
# mbce57qndc-algo-1-yek3h | /usr/bin/python3 cifar10_keras_sm_ddp_tf2.py --epochs 1 --model_dir s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-09-30-963/model
# mbce57qndc-algo-1-yek3h |
# mbce57qndc-algo-1-yek3h |
# mbce57qndc-algo-1-yek3h | Step #0	Loss: 3.882393
# mbce57qndc-algo-1-yek3h | Step #10	Loss: 2.703118
# mbce57qndc-algo-1-yek3h | Step #20	Loss: 2.190347
# mbce57qndc-algo-1-yek3h | Step #30	Loss: 2.167863
# mbce57qndc-algo-1-yek3h | Step #40	Loss: 2.172101
# mbce57qndc-algo-1-yek3h | 2021-02-22 06:10:55,841 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# mbce57qndc-algo-1-yek3h | For details of how to construct your training script see:
# mbce57qndc-algo-1-yek3h | https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# mbce57qndc-algo-1-yek3h | 2021-02-22 06:10:55,842 sagemaker-containers INFO     Reporting training SUCCESS
# mbce57qndc-algo-1-yek3h exited with code 0
# Aborting on container exit...
# ===== Job Complete =====
# CPU times: user 340 ms, sys: 50 ms, total: 390 ms
# Wall time: 1min 25s

# %% [markdown]
# # (4) Using SageMaker for faster training time

# %%
dataset_location = sagemaker_session.upload_data(path='data', key_prefix='data/DEMO-cifar10')
display(dataset_location)
# Out:
# 's3://sagemaker-ap-northeast-2-057716757052/data/DEMO-cifar10'

# %%
pip install --upgrade sagemaker
# Out:
# Requirement already satisfied: sagemaker in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (2.25.1)
# Requirement already satisfied: boto3>=1.16.32 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (1.16.63)
# Requirement already satisfied: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (3.14.0)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (20.8)
# Requirement already satisfied: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (1.18.5)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (0.1.5)
# Requirement already satisfied: importlib-metadata>=1.4.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (3.4.0)
# Requirement already satisfied: attrs in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (20.3.0)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: botocore<1.20.0,>=1.19.63 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (1.19.63)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (0.3.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from botocore<1.20.0,>=1.19.63->boto3>=1.16.32->sagemaker) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from botocore<1.20.0,>=1.19.63->boto3>=1.16.32->sagemaker) (1.26.2)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from packaging>=20.0->sagemaker) (2.4.7)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker) (1.15.0)
# WARNING: You are using pip version 20.3.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/tensorflow2_p36/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%time

estimator = TensorFlow(base_job_name='cifar10-ddp',
                       entry_point='cifar10_keras_sm_ddp_tf2.py',
                       source_dir='training_script',
                       role=role,
                       framework_version='2.3',
                       py_version='py37',
                       hyperparameters={'epochs': 1},
                       train_instance_count=1, 
                       train_instance_type='ml.p3.16xlarge',
                       wait=True,
                       # Training using smdistributed.dataparallel Distributed Training Framework
                       # distribution={"smdistributed": {"dataparallel": {"enabled": True}}}
                      )


estimator.fit({'train':'{}/train'.format(dataset_location),
              'validation':'{}/validation'.format(dataset_location),
              'eval':'{}/eval'.format(dataset_location)})
# Out:
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2021-02-22 06:30:43 Starting - Starting the training job...
# 2021-02-22 06:31:06 Starting - Launching requested ML instancesProfilerReport-1613975442: InProgress
# .........
# 2021-02-22 06:32:27 Starting - Preparing the instances for training.........
# 2021-02-22 06:34:08 Downloading - Downloading input data
# 2021-02-22 06:34:08 Training - Downloading the training image...........2021-02-22 06:35:47.390393: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-02-22 06:35:47.396057: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-02-22 06:35:47.640057: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.2
# 2021-02-22 06:35:47.734419: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-02-22 06:35:50,795 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-02-22 06:35:51,496 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "validation": "/opt/ml/input/data/validation",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://sagemaker-ap-northeast-2-057716757052/cifar10-ddp-2021-02-22-06-30-42-414/model",
#         "epochs": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "cifar10-ddp-2021-02-22-06-30-42-414",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-northeast-2-057716757052/cifar10-ddp-2021-02-22-06-30-42-414/source/sourcedir.tar.gz",
#     "module_name": "cifar10_keras_sm_ddp_tf2",
#     "network_interface_name": "eth0",
#     "num_cpus": 64,
#     "num_gpus": 8,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "cifar10_keras_sm_ddp_tf2.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":1,"model_dir":"s3://sagemaker-ap-northeast-2-057716757052/cifar10-ddp-2021-02-22-06-30-42-414/model"}
# SM_USER_ENTRY_POINT=cifar10_keras_sm_ddp_tf2.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=cifar10_keras_sm_ddp_tf2
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=64
# SM_NUM_GPUS=8
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-057716757052/cifar10-ddp-2021-02-22-06-30-42-414/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":1,"model_dir":"s3://sagemaker-ap-northeast-2-057716757052/cifar10-ddp-2021-02-22-06-30-42-414/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"cifar10-ddp-2021-02-22-06-30-42-414","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-057716757052/cifar10-ddp-2021-02-22-06-30-42-414/source/sourcedir.tar.gz","module_name":"cifar10_keras_sm_ddp_tf2","network_interface_name":"eth0","num_cpus":64,"num_gpus":8,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"cifar10_keras_sm_ddp_tf2.py"}
# SM_USER_ARGS=["--epochs","1","--model_dir","s3://sagemaker-ap-northeast-2-057716757052/cifar10-ddp-2021-02-22-06-30-42-414/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_DIR=s3://sagemaker-ap-northeast-2-057716757052/cifar10-ddp-2021-02-22-06-30-42-414/model
# SM_HP_EPOCHS=1
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /usr/local/bin/python3.7 cifar10_keras_sm_ddp_tf2.py --epochs 1 --model_dir s3://sagemaker-ap-northeast-2-057716757052/cifar10-ddp-2021-02-22-06-30-42-414/model
#
#
#
# 2021-02-22 06:36:10 Training - Training image download completed. Training in progress.[2021-02-22 06:36:02.749 ip-10-0-73-63.ap-northeast-2.compute.internal:144 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2021-02-22 06:36:03.030 ip-10-0-73-63.ap-northeast-2.compute.internal:144 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2021-02-22 06:36:04.667 ip-10-0-73-63.ap-northeast-2.compute.internal:144 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2021-02-22 06:36:04.668 ip-10-0-73-63.ap-northeast-2.compute.internal:144 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2021-02-22 06:36:04.669 ip-10-0-73-63.ap-northeast-2.compute.internal:144 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2021-02-22 06:36:04.669 ip-10-0-73-63.ap-northeast-2.compute.internal:144 INFO state_store.py:75] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2021-02-22 06:36:04.670 ip-10-0-73-63.ap-northeast-2.compute.internal:144 INFO hook.py:413] Monitoring the collections: sm_metrics, metrics, losses
# Step #0#011Loss: 4.351995
# Step #10#011Loss: 2.353435
# Step #20#011Loss: 2.189100
# Step #30#011Loss: 2.009306
# Step #40#011Loss: 2.095997
# 2021-02-22 06:35:51.826714: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-02-22 06:35:51.826893: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-02-22 06:35:51.869583: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
#
# 2021-02-22 06:36:12,728 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# 2021-02-22 06:36:12,728 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2021-02-22 06:36:30 Uploading - Uploading generated training model
# 2021-02-22 06:36:30 Completed - Training job completed
# Training seconds: 150
# Billable seconds: 150
# CPU times: user 1.09 s, sys: 0 ns, total: 1.09 s
# Wall time: 6min 13s

# %% [markdown]
# 학습을 수행합니다. 이번에는 각각의 채널(`train, validation, eval`)에 S3의 데이터 저장 위치를 지정합니다.<br>
# 학습 완료 후 Billable seconds도 확인해 보세요. Billable seconds는 실제로 학습 수행 시 과금되는 시간입니다.
# ```
# Billable seconds: <time>
# ```
#
# 참고로, `ml.p2.xlarge` 인스턴스로 5 epoch 학습 시 전체 6분-7분이 소요되고, 실제 학습에 소요되는 시간은 3분-4분이 소요됩니다.

# %%
# Out:
# 2021-02-22 06:11:46 Starting - Starting the training job...
# 2021-02-22 06:12:11 Starting - Launching requested ML instancesProfilerReport-1613974305: InProgress
# .........
# 2021-02-22 06:13:46 Starting - Preparing the instances for training......
# 2021-02-22 06:14:37 Downloading - Downloading input data...
# 2021-02-22 06:15:13 Training - Downloading the training image...
# 2021-02-22 06:15:34 Training - Training image download completed. Training in progress.2021-02-22 06:15:34,621 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-02-22 06:15:35,163 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "validation": "/opt/ml/input/data/validation",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-11-45-559/model",
#         "epochs": 2
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "cifar10-2021-02-22-06-11-45-559",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-11-45-559/source/sourcedir.tar.gz",
#     "module_name": "cifar10_keras_sm_tf2",
#     "network_interface_name": "eth0",
#     "num_cpus": 32,
#     "num_gpus": 4,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "cifar10_keras_sm_tf2.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":2,"model_dir":"s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-11-45-559/model"}
# SM_USER_ENTRY_POINT=cifar10_keras_sm_tf2.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=cifar10_keras_sm_tf2
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=32
# SM_NUM_GPUS=4
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-11-45-559/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":2,"model_dir":"s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-11-45-559/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"cifar10-2021-02-22-06-11-45-559","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-11-45-559/source/sourcedir.tar.gz","module_name":"cifar10_keras_sm_tf2","network_interface_name":"eth0","num_cpus":32,"num_gpus":4,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"cifar10_keras_sm_tf2.py"}
# SM_USER_ARGS=["--epochs","2","--model_dir","s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-11-45-559/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_DIR=s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-11-45-559/model
# SM_HP_EPOCHS=2
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 cifar10_keras_sm_tf2.py --epochs 2 --model_dir s3://sagemaker-ap-northeast-2-057716757052/cifar10-2021-02-22-06-11-45-559/model
#
#
# Train for 312 steps, validate for 78 steps
# Epoch 1/2
# #015  1/312 [..............................] - ETA: 36:11 - loss: 4.3385 - accuracy: 0.1250#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  7/312 [..............................] - ETA: 5:06 - loss: 3.4950 - accuracy: 0.1261 #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 13/312 [>.............................] - ETA: 2:43 - loss: 3.1277 - accuracy: 0.1400#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 19/312 [>.............................] - ETA: 1:50 - loss: 2.9083 - accuracy: 0.1377#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 26/312 [=>............................] - ETA: 1:19 - loss: 2.7205 - accuracy: 0.1499#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 33/312 [==>...........................] - ETA: 1:01 - loss: 2.5959 - accuracy: 0.1641#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 40/312 [==>...........................] - ETA: 49s - loss: 2.5090 - accuracy: 0.1734 #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 47/312 [===>..........................] - ETA: 41s - loss: 2.4456 - accuracy: 0.1800#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 54/312 [====>.........................] - ETA: 35s - loss: 2.3929 - accuracy: 0.1862#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 61/312 [====>.........................] - ETA: 30s - loss: 2.3454 - accuracy: 0.1938#010#010#010# ...
# Epoch 2/2
# #015  1/312 [..............................] - ETA: 3s - loss: 1.6921 - accuracy: 0.3672#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  8/312 [..............................] - ETA: 2s - loss: 1.6114 - accuracy: 0.3945#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 15/312 [>.............................] - ETA: 2s - loss: 1.6042 - accuracy: 0.4031#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 22/312 [=>............................] - ETA: 2s - loss: 1.5973 - accuracy: 0.4031#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 29/312 [=>............................] - ETA: 2s - loss: 1.5955 - accuracy: 0.4060#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 36/312 [==>...........................] - ETA: 2s - loss: 1.5917 - accuracy: 0.4123#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 43/312 [===>..........................] - ETA: 2s - loss: 1.5887 - accuracy: 0.4175#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 50/312 [===>..........................] - ETA: 2s - loss: 1.5912 - accuracy: 0.4166#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 57/312 [====>.........................] - ETA: 2s - loss: 1.5812 - accuracy: 0.4200#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 63/312 [=====>........................] - ETA: 1s - loss: 1.5815 - accuracy: 0.4196#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010 ...
#
# 2021-02-22 06:22:19 Uploading - Uploading generated training model2021-02-22 06:22:11.602197: W tensorflow/python/util/util.cc:299] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# 2021-02-22 06:22:15,066 sagemaker-containers INFO     Reporting training SUCCESS
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     659         self.jobs.append(self.latest_training_job)
#     660         if wait:
# --> 661             self.latest_training_job.wait(logs=logs)
#     662
#     663     def _compilation_job_name(self):
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1586         # If logs are requested, call logs_for_jobs.
#    1587         if logs != "None":
# -> 1588             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1589         else:
#    1590             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3588                 break
#    3589
# -> 3590             time.sleep(poll)
#    3591
#    3592             if state == LogState.JOB_COMPLETE:
#
# KeyboardInterrupt:

# %%
# %store dataset_location
# Out:
# Stored 'dataset_location' (str)

# %% [markdown]
# ## (5) DDP

# %%
from sagemaker.tensorflow import TensorFlow
pt_estimator = TensorFlow(
                        base_job_name='tensorflow2-smdataparallel-mnist',
                        source_dir='training_script',    
                        entry_point='cifar10_keras_sm_ddp_81.py',
                        role=role,
                        py_version='py37',
                        framework_version='2.3.1',
                        # For training with multinode distributed training, set this count. Example: 2
                        instance_count=2,
                        # For training with p3dn instance use - ml.p3dn.24xlarge, with p4dn instance use - ml.p4d.24xlarge
                        instance_type= 'ml.p3.16xlarge',
                        sagemaker_session=sagemaker_session,
                        # Training using SMDataParallel Distributed Training Framework
                        distribution={'smdistributed':{
                                            'dataparallel':{
                                                    'enabled': True
                                             }
                                      }}
                        )
pt_estimator.fit({'train':'{}/train'.format(dataset_location),
              'validation':'{}/validation'.format(dataset_location),
              'eval':'{}/eval'.format(dataset_location)})
# Out:
# 2021-02-22 13:07:19 Starting - Starting the training job...
# 2021-02-22 13:07:44 Starting - Launching requested ML instancesProfilerReport-1613999239: InProgress
# .........
# 2021-02-22 13:09:17 Starting - Preparing the instances for training.........
# 2021-02-22 13:10:46 Downloading - Downloading input data...
# 2021-02-22 13:11:06 Training - Downloading the training image............
# 2021-02-22 13:13:16 Training - Training image download completed. Training in progress..2021-02-22 13:13:16.760556: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-02-22 13:13:16.765568: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-02-22 13:13:17.000480: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.11.0
# 2021-02-22 13:13:17.095777: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-02-22 13:13:15.989886: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-02-22 13:13:15.995726: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-02-22 13:13:16.224077: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.11.0
# 2021-02-22 13:13:16.315513: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-02-22 13:13:19,461 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-02-22 13:13:20,594 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-02-22 13:13:20,128 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2021-02-22 13:13:20,128 sagemaker-training-toolkit INFO     Creating SSH daemon.
# 2021-02-22 13:13:20,136 sagemaker-training-toolkit INFO     Waiting for MPI workers to establish their SSH connections
# 2021-02-22 13:13:20,138 sagemaker-training-toolkit INFO     Cannot connect to host algo-2 at port 22
# 2021-02-22 13:13:20,138 sagemaker-training-toolkit ERROR    Connection failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/sagemaker_training/smdataparallel.py", line 306, in _can_connect
#     client.connect(host, port=port)
#   File "/usr/local/lib/python3.7/site-packages/paramiko/client.py", line 368, in connect
#     raise NoValidConnectionsError(errors)
# paramiko.ssh_exception.NoValidConnectionsError: [Errno None] Unable to connect to port 22 on 10.0.152.94
# 2021-02-22 13:13:20,140 sagemaker-training-toolkit INFO     Connection closed
# 2021-02-22 13:13:21,309 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2021-02-22 13:13:21,309 sagemaker-training-toolkit INFO     Waiting for MPI Master to create SSH daemon.
# 2021-02-22 13:13:21,317 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# 2021-02-22 13:13:21,389 paramiko.transport INFO     Authentication (publickey) successful!
# 2021-02-22 13:13:21,389 sagemaker-training-toolkit INFO     Can connect to host algo-1
# 2021-02-22 13:13:21,389 sagemaker-training-toolkit INFO     MPI Master online, creating SSH daemon.
# 2021-02-22 13:13:21,389 sagemaker-training-toolkit INFO     Writing environment variables to /etc/environment for the MPI process.
# 2021-02-22 13:13:21,399 sagemaker-training-toolkit INFO     Waiting for MPI process to finish.
# 2021-02-22 13:13:21,142 sagemaker-training-toolkit INFO     Cannot connect to host algo-2 at port 22
# 2021-02-22 13:13:21,142 sagemaker-training-toolkit ERROR    Connection failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/sagemaker_training/smdataparallel.py", line 306, in _can_connect
#     client.connect(host, port=port)
#   File "/usr/local/lib/python3.7/site-packages/paramiko/client.py", line 368, in connect
#     raise NoValidConnectionsError(errors)
# paramiko.ssh_exception.NoValidConnectionsError: [Errno None] Unable to connect to port 22 on 10.0.152.94
# 2021-02-22 13:13:21,142 sagemaker-training-toolkit INFO     Connection closed
# 2021-02-22 13:13:22,152 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# 2021-02-22 13:13:22,225 paramiko.transport INFO     Authentication (publickey) successful!
# 2021-02-22 13:13:22,226 sagemaker-training-toolkit INFO     Can connect to host algo-2 at port 22
# 2021-02-22 13:13:22,226 sagemaker-training-toolkit INFO     Connection closed
# 2021-02-22 13:13:22,226 sagemaker-training-toolkit INFO     Worker algo-2 available for communication
# 2021-02-22 13:13:22,226 sagemaker-training-toolkit INFO     Network interface name: eth0
# 2021-02-22 13:13:22,226 sagemaker-training-toolkit INFO     Host: ['algo-1', 'algo-2']
# 2021-02-22 13:13:22,226 sagemaker-training-toolkit INFO     instance type: ml.p3.16xlarge
# 2021-02-22 13:13:22,315 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_distributed_dataparallel_enabled": true,
#         "sagemaker_instance_type": "ml.p3.16xlarge"
#     },
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "validation": "/opt/ml/input/data/validation",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/source/sourcedir.tar.gz",
#     "module_name": "cifar10_keras_sm_ddp_81",
#     "network_interface_name": "eth0",
#     "num_cpus": 64,
#     "num_gpus": 8,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "cifar10_keras_sm_ddp_81.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"model_dir":"s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model"}
# SM_USER_ENTRY_POINT=cifar10_keras_sm_ddp_81.py
# SM_FRAMEWORK_PARAMS={"sagemaker_distributed_dataparallel_enabled":true,"sagemaker_instance_type":"ml.p3.16xlarge"}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=cifar10_keras_sm_ddp_81
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=64
# SM_NUM_GPUS=8
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_distributed_dataparallel_enabled":true,"sagemaker_instance_type":"ml.p3.16xlarge"},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"model_dir":"s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/source/sourcedir.tar.gz","module_name":"cifar10_keras_sm_ddp_81","network_interface_name":"eth0","num_cpus":64,"num_gpus":8,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"cifar10_keras_sm_ddp_81.py"}
# SM_USER_ARGS=["--model_dir","s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_DIR=s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# mpirun --host algo-1:8,algo-2:8 -np 16 --allow-run-as-root --tag-output --oversubscribe -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -mca btl_vader_single_copy_mechanism none -mca plm_rsh_num_concurrent 2 -x NCCL_SOCKET_IFNAME=eth0 -x LD_LIBRARY_PATH -x PATH -x SMDATAPARALLEL_USE_HOMOGENEOUS=1 -x FI_PROVIDER=sockets -x RDMAV_FORK_SAFE=1 -x LD_PRELOAD=/usr/local/lib/python3.7/site-packages/gethostname.cpython-37m-x86_64-linux-gnu.so -x SMDATAPARALLEL_SERVER_ADDR=algo-1 -x SMDATAPARALLEL_SERVER_PORT=7592 -x SAGEMAKER_INSTANCE_TYPE=ml.p3.16xlarge smddprun /usr/local/bin/python3.7 -m mpi4py cifar10_keras_sm_ddp_81.py --model_dir s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model
#
#
# 2021-02-22 13:13:23,404 sagemaker-training-toolkit INFO     Process[es]: [psutil.Process(pid=170, name='orted', status='disk-sleep', started='13:13:23')]
# 2021-02-22 13:13:23,404 sagemaker-training-toolkit INFO     Orted process found [psutil.Process(pid=170, name='orted', status='disk-sleep', started='13:13:23')]
# 2021-02-22 13:13:23,404 sagemaker-training-toolkit INFO     Waiting for orted process [psutil.Process(pid=170, name='orted', status='disk-sleep', started='13:13:23')]
# [1,0]<stdout>:[2021-02-22 13:13:46.607 algo-1:168 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,1]<stdout>:[2021-02-22 13:13:46.607 algo-1:170 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,3]<stdout>:[2021-02-22 13:13:46.608 algo-1:173 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,0]<stdout>:[2021-02-22 13:13:46.686 algo-1:168 INFO profiler_config_parser.py:102] User has disabled profiler.
# [1,1]<stdout>:[2021-02-22 13:13:46.686 algo-1:170 INFO profiler_config_parser.py:102] User has disabled profiler.
# [1,3]<stdout>:[2021-02-22 13:13:46.686 algo-1:173 INFO profiler_config_parser.py:102] User has disabled profiler.
# [1,9]<stdout>:[2021-02-22 13:13:46.701 algo-2:179 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,11]<stdout>:[2021-02-22 13:13:46.701 algo-2:182 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,15]<stdout>:[2021-02-22 13:13:46.701 algo-2:188 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,9]<stdout>:[2021-02-22 13:13:46.801 algo-2:179 INFO profiler_config_parser.py:102] User has disabled profiler.
# [1,11]<stdout>:[2021-02-22 13:13:46.801 algo-2:182 INFO profiler_config_parser.py:102] User has disabled profiler.
# [1,15]<stdout>:[2021-02-22 13:13:46.801 algo-2:188 INFO profiler_config_parser.py:102] User has disabled profiler.
# [1,5]<stdout>:[2021-02-22 13:14:02.560 algo-1:177 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,5]<stdout>:[2021-02-22 13:14:02.594 algo-1:177 INFO profiler_config_parser.py:102] User has disabled profiler.
# [1,14]<stdout>:[2021-02-22 13:14:02.602 algo-2:187 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,14]<stdout>:[2021-02-22 13:14:02.635 algo-2:187 INFO profiler_config_parser.py:102] User has disabled profiler.
# 2021-02-22 13:14:06,062 sagemaker-training-toolkit INFO     Orted process exited
# [1,14]<stdout>:[2021-02-22 13:14:04.326 algo-2:187 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,14]<stdout>:[2021-02-22 13:14:04.327 algo-2:187 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# Warning: Permanently added 'algo-2,10.0.152.94' (ECDSA) to the list of known hosts.#015
# [1,1]<stderr>:2021-02-22 13:13:23.960339: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,4]<stderr>:2021-02-22 13:13:23.960339: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,1]<stderr>:2021-02-22 13:13:23.960545: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,4]<stderr>:2021-02-22 13:13:23.960545: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,0]<stderr>:2021-02-22 13:13:23.963377: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,2]<stderr>:2021-02-22 13:13:23.963379: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,5]<stderr>:2021-02-22 13:13:23.963379: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,0]<stderr>:2021-02-22 13:13:23.963565: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,2]<stderr>:2021-02-22 13:13:23.963565: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,5]<stderr>:2021-02-22 13:13:23.963565: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,9]<stderr>:2021-02-22 13:13:23.983113: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,9]<stderr>:2021-02-22 13:13:23.983303: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,6]<stderr>:2021-02-22 13:13:23.989005: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,6]<stderr>:2021-02-22 13:13:23.989190: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,4]<stderr>:2021-02-22 13:13:24.003301: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,1]<stderr>:2021-02-22 13:13:24.003744: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,2]<stderr>:2021-02-22 13:13:24.005368: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,0]<stderr>:2021-02-22 13:13:24.005354: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,5]<stderr>:2021-02-22 13:13:24.005460: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,15]<stderr>:2021-02-22 13:13:24.009642: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,15]<stderr>:2021-02-22 13:13:24.009803: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,8]<stderr>:2021-02-22 13:13:24.011423: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,10]<stderr>:2021-02-22 13:13:24.011476: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,14]<stderr>:2021-02-22 13:13:24.011425: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,8]<stderr>:2021-02-22 13:13:24.011644: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,14]<stderr>:2021-02-22 13:13:24.011647: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,10]<stderr>:2021-02-22 13:13:24.011655: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,12]<stderr>:2021-02-22 13:13:24.013084: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,12]<stderr>:2021-02-22 13:13:24.013228: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,7]<stderr>:2021-02-22 13:13:24.023389: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,7]<stderr>:2021-02-22 13:13:24.023560: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,9]<stderr>:2021-02-22 13:13:24.026349: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,6]<stderr>:2021-02-22 13:13:24.031376: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,3]<stderr>:2021-02-22 13:13:24.041903: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,11]<stderr>:2021-02-22 13:13:24.041337: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,11]<stderr>:2021-02-22 13:13:24.041538: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,3]<stderr>:2021-02-22 13:13:24.042060: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,13]<stderr>:2021-02-22 13:13:24.042147: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,13]<stderr>:2021-02-22 13:13:24.042283: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,15]<stderr>:2021-02-22 13:13:24.050804: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,10]<stderr>:2021-02-22 13:13:24.052033: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,8]<stderr>:2021-02-22 13:13:24.053928: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,14]<stderr>:2021-02-22 13:13:24.053980: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,12]<stderr>:2021-02-22 13:13:24.054336: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,7]<stderr>:2021-02-22 13:13:24.065941: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,3]<stderr>:2021-02-22 13:13:24.083849: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,13]<stderr>:2021-02-22 13:13:24.084380: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,11]<stderr>:2021-02-22 13:13:24.084387: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,1]<stderr>:2021-02-22 13:13:46.758000: F ./tensorflow/core/kernels/random_op_gpu.h:232] Non-OK-status: GpuLaunchKernel(FillPhiloxRandomKernelLaunch<Distribution>, num_blocks, block_size, 0, d.stream(), gen, data, size, dist) status: Internal: out of memory
# [1,0]<stderr>:2021-02-22 13:13:46.759745: F ./tensorflow/core/kernels/random_op_gpu.h:232] Non-OK-status: GpuLaunchKernel(FillPhiloxRandomKernelLaunch<Distribution>, num_blocks, block_size, 0, d.stream(), gen, data, size, dist) status: Internal: out of memory
# [1,3]<stderr>:2021-02-22 13:13:46.762424: F ./tensorflow/core/kernels/random_op_gpu.h:232] Non-OK-status: GpuLaunchKernel(FillPhiloxRandomKernelLaunch<Distribution>, num_blocks, block_size, 0, d.stream(), gen, data, size, dist) status: Internal: out of memory
# 2021-02-22 13:14:06,060 sagemaker-training-toolkit ERROR    ExecuteUserScriptError:
# Command "mpirun --host algo-1:8,algo-2:8 -np 16 --allow-run-as-root --tag-output --oversubscribe -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -mca btl_vader_single_copy_mechanism none -mca plm_rsh_num_concurrent 2 -x NCCL_SOCKET_IFNAME=eth0 -x LD_LIBRARY_PATH -x PATH -x SMDATAPARALLEL_USE_HOMOGENEOUS=1 -x FI_PROVIDER=sockets -x RDMAV_FORK_SAFE=1 -x LD_PRELOAD=/usr/local/lib/python3.7/site-packages/gethostname.cpython-37m-x86_64-linux-gnu.so -x SMDATAPARALLEL_SERVER_ADDR=algo-1 -x SMDATAPARALLEL_SERVER_PORT=7592 -x SAGEMAKER_INSTANCE_TYPE=ml.p3.16xlarge smddprun /usr/local/bin/python3.7 -m mpi4py cifar10_keras_sm_ddp_81.py --model_dir s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model"
# Warning: Permanently added 'algo-2,10.0.152.94' (ECDSA) to the list of known hosts.#015
# [1,1]<stderr>:2021-02-22 13:13:23.960339: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,4]<stderr>:2021-02-22 13:13:23.960339: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,1]<stderr>:2021-02-22 13:13:23.960545: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,4]<stderr>:2021-02-22 13:13:23.960545: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,0]<stderr>:2021-02-22 13:13:23.963377: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,2]<stderr>:2021-02-22 13:13:23.963379: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,5]<stderr>:2021-02-22 13:13:23.963379: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,0]<stderr>:2021-02-22 13:13:23.963565: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,9]<stderr>:2021-02-22 13:13:46.869168: F ./tensorflow/core/kernels/random_op_gpu.h:232] Non-OK-status: GpuLaunchKernel(FillPhiloxRandomKernelLaunch<Distribution>, num_blocks, block_size, 0, d.stream(), gen, data, size, dist) status: Internal: out of memory
# [1,15]<stderr>:2021-02-22 13:13:46.873003: F ./tensorflow/core/kernels/random_op_gpu.h:232] Non-OK-status: GpuLaunchKernel(FillPhiloxRandomKernelLaunch<Distribution>, num_blocks, block_size, 0, d.stream(), gen, data, size, dist) status: Internal: out of memory
# [1,11]<stderr>:2021-02-22 13:13:46.874148: F ./tensorflow/core/kernels/random_op_gpu.h:232] Non-OK-status: GpuLaunchKernel(FillPhiloxRandomKernelLaunch<Distribution>, num_blocks, block_size, 0, d.stream(), gen, data, size, dist) status: Internal: out of memory
# [1,1]<stderr>:/usr/local/bin/smddprun: line 258:   170 Aborted                 /usr/local/bin/python3.7 -m mpi4py cifar10_keras_sm_ddp_81.py --model_dir s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model
# [1,0]<stderr>:/usr/local/bin/smddprun: line 258:   168 Aborted                 /usr/local/bin/python3.7 -m mpi4py cifar10_keras_sm_ddp_81.py --model_dir s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model
# [1,3]<stderr>:/usr/local/bin/smddprun: line 258:   173 Aborted                 /usr/local/bin/python3.7 -m mpi4py cifar10_keras_sm_ddp_81.py --model_dir s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model
# --------------------------------------------------------------------------
# Primary job  terminated normally, but 1 process returned
# a non-zero exit code. Per user-direction, the job has been aborted.
# --------------------------------------------------------------------------
# [1,11]<stderr>:/usr/local/bin/smddprun: line 258:   182 Aborted                 /usr/local/bin/python3.7 -m mpi4py cifar10_keras_sm_ddp_81.py --model_dir s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model
# [1,15]<stderr>:/usr/local/bin/smddprun: line 258:   188 Aborted                 /usr/local/bin/python3.7 -m mpi4py cifar10_keras_sm_ddp_81.py --model_dir s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model
# [1,9]<stderr>:/usr/local/bin/smddprun: line 258:   179 Aborted                 /usr/local/bin/python3.7 -m mpi4py cifar10_keras_sm_ddp_81.py --model_dir s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model
# --------------------------------------------------------------------------
# mpirun.real detected that one or more processes exited with non-zero status, thus causing
# the job to be terminated. The first process to do so was:
#
#   Process name: [[44239,1],0]
# [1,2]<stderr>:2021-02-22 13:13:23.963565: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,5]<stderr>:2021-02-22 13:13:23.963565: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,9]<stderr>:2021-02-22 13:13:23.983113: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,9]<stderr>:2021-02-22 13:13:23.983303: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,6]<stderr>:2021-02-22 13:13:23.989005: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,6]<stderr>:2021-02-22 13:13:23.989190: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,4]<stderr>:2021-02-22 13:13:24.003301: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,1]<stderr>:2021-02-22 13:13:24.003744: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,2]<stderr>:2021-02-22 13:13:24.005368: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,0]<stderr>:2021-02-22 13:13:24.005354: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,5]<stderr>:2021-02-22 13:13:24.005460: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,15]<stderr>:2021-02-22 13:13:24.009642: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
#   Exit code:    134
# --------------------------------------------------------------------------
# [1,15]<stderr>:2021-02-22 13:13:24.009803: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,8]<stderr>:2021-02-22 13:13:24.011423: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,10]<stderr>:2021-02-22 13:13:24.011476: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,14]<stderr>:2021-02-22 13:13:24.011425: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,8]<stderr>:2021-02-22 13:13:24.011644: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,14]<stderr>:2021-02-22 13:13:24.011647: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,10]<stderr>:2021-02-22 13:13:24.011655: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,12]<stderr>:2021-02-22 13:13:24.013084: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,12]<stderr>:2021-02-22 13:13:24.013228: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,7]<stderr>:2021-02-22 13:13:24.023389: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,7]<stderr>:2021-02-22 13:13:24.023560: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,9]<stderr>:2021-02-22 13:13:24.026349: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,6]<stderr>:2021-02-22 13:13:24.031376: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,3]<stderr>:2021-02-22 13:13:24.041903: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,11]<stderr>:2021-02-22 13:13:24.041337: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,11]<stderr>:2021-02-22 13:13:24.041538: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,3]<stderr>:2021-02-22 13:13:24.042060: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,13]<stderr>:2021-02-22 13:13:24.042147: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,13]<stderr>:2021-02-22 13:13:24.042283: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,15]<stderr>:2021-02-22 13:13:24.050804: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,10]<stderr>:2021-02-22 13:13:24.052033: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,8]<stderr>:2021-02-22 13:13:24.053928: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
#
# [1,14]<stderr>:2021-02-22 13:13:24.053980: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,12]<stderr>:2021-02-22 13:13:24.054336: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,7]<stderr>:2021-02-22 13:13:24.065941: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,3]<stderr>:2021-02-22 13:13:24.083849: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,13]<stderr>:2021-02-22 13:13:24.084380: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,11]<stderr>:2021-02-22 13:13:24.084387: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,1]<stderr>:2021-02-22 13:13:46.758000: F ./tensorflow/core/kernels/random_op_gpu.h:232] Non-OK-status: GpuLaunchKernel(FillPhiloxRandomKernelLaunch<Distribution>, num_blocks, block_size, 0, d.stream(), gen, data, size, dist) status: Internal: out of memory
# [1,0]<stderr>:2021-02-22 13:13:46.759745: F ./tensorflow/core/kernels/random_op_gpu.h:232] Non-OK-status: GpuLaunchKernel(FillPhiloxRandomKernelLaunch<Distribution>, num_blocks, block_size, 0, d.stream(), gen, data, size, dist) status: Internal: out of memory
# [1,3]<stderr>:2021-02-22 13:13:46.762424: F ./tensorflow/core/kernels/random_op_gpu.h:232] Non-OK-status: GpuLaunchKernel(FillPhiloxRandomKernelLaunch<Distribution>, num_blocks, block_size, 0, d.stream(), gen, data, size, dist) status: Internal: out of memory
# [1,9]<stderr>:2021-02-22 13:13:46.869168: F ./tensorflow/core/kernels/random_op_gpu.h:232] Non-OK-status: GpuLaunchKernel(FillPhiloxRandomKernelLaunch<Distribution>, num_blocks, block_size, 0, d.stream(), gen, data, size, dist) status: Internal: out of memory
# [1,15]<stderr>:2021-02-22 13:13:46.873003: F ./tensorflow/core/kernels/random_op_gpu.h:232] Non-OK-status: GpuLaunchKernel(FillPhiloxRandomKernelLaunch<Distribution>, num_blocks, block_size, 0, d.stream(), gen, data, size, dist) status: Internal: out of memory
# [1,11]<stderr>:2021-02-22 13:13:46.874148: F ./tensorflow/core/kernels/random_op_gpu.h:232] Non-OK-status: GpuLaunchKernel(FillPhiloxRandomKernelLaunch<Distribution>, num_blocks, block_size, 0, d.stream(), gen, data, size, dist) status: Internal: out of memory
# [1,1]<stderr>:/usr/local/bin/smddprun: line 258:   170 Aborted                 /usr/local/bin/python3.7 -m mpi4py cifar10_keras_sm_ddp_81.py --model_dir s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model
# [1,0]<stderr>:/usr/local/bin/smddprun: line 258:   168 Aborted                 /usr/local/bin/python3.7 -m mpi4py cifar10_keras_sm_ddp_81.py --model_dir s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model
# [1,3]<stderr>:/usr/local/bin/smddprun: line 258:   173 Aborted                 /usr/local/bin/python3.7 -m mpi4py cifar10_keras_sm_ddp_81.py --model_dir s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model
# --------------------------------------------------------------------------
# Primary job  terminated normally, but 1 process returned
# a non-zero exit code. Per user-direction, the job has been aborted.
# --------------------------------------------------------------------------
# [1,11]<stderr>:/usr/local/bin/smddprun: line 258:   182 Aborted                 /usr/local/bin/python3.7 -m mpi4py cifar10_keras_sm_ddp_81.py --model_dir s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model
# [1,15]<stderr>:/usr/local/bin/smddprun: line 258:   188 Aborted                 /usr/local/bin/python3.7 -m mpi4py cifar10_keras_sm_ddp_81.py --model_dir s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model
# [1,9]<stderr>:/usr/local/bin/smddprun: line 258:   179 Aborted                 /usr/local/bin/python3.7 -m mpi4py cifar10_keras_sm_ddp_81.py --model_dir s3://sagemaker-ap-northeast-2-057716757052/tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068/model
# --------------------------------------------------------------------------
# mpirun.real detected that one or more processes exited with non-zero status, thus causing
# the job to be terminated. The first process to do so was:
#
#   Process name: [[44239,1],0]
#   Exit code:    134
# --------------------------------------------------------------------------
# 2021-02-22 13:14:36,093 sagemaker-training-toolkit INFO     MPI process finished.
# 2021-02-22 13:14:36,093 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# 2021-02-22 13:14:36,093 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2021-02-22 13:14:49 Failed - Training job failed
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-22-5fede71a95dd> in <module>
#      21 pt_estimator.fit({'train':'{}/train'.format(dataset_location),
#      22               'validation':'{}/validation'.format(dataset_location),
# ---> 23               'eval':'{}/eval'.format(dataset_location)})
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     659         self.jobs.append(self.latest_training_job)
#     660         if wait:
# --> 661             self.latest_training_job.wait(logs=logs)
#     662
#     663     def _compilation_job_name(self):
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1586         # If logs are requested, call logs_for_jobs.
#    1587         if logs != "None":
# -> 1588             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1589         else:
#    1590             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3638
#    3639         if wait:
# -> 3640             self._check_job_status(job_name, description, "TrainingJobStatus")
#    3641             if dot:
#    3642                 print()
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#    3220                 ),
#    3221                 allowed_statuses=["Completed", "Stopped"],
# -> 3222                 actual_status=status,
#    3223             )
#    3224
#
# UnexpectedStatusException: Error for Training job tensorflow2-smdataparallel-mnist-2021-02-22-13-07-19-068: Failed. Reason: InternalServerError: We encountered an internal error. Please try again.
