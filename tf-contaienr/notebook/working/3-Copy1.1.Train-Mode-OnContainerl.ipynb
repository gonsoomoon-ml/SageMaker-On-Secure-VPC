# %% [markdown]
# # [모듈 2.1] SageMaker 클러스터에서 훈련 (No VPC에서 실행)
#
# 이 노트북은 아래의 작업을 실행 합니다.
# - SageMaker Hosting Cluster 에서 훈련을 실행
# - 훈련한 Job 이름을 저장
#     - 다음 노트북에서 모델 배포 및 추론시에 사용 합니다.
# ---

# %% [markdown]
# SageMaker의 세션을 얻고, role 정보를 가져옵니다.
# - 위의 두 정보를 통해서 SageMaker Hosting Cluster에 연결합니다.

# %%
# import boto3
# import sagemaker
# from sagemaker import get_execution_role

# ecr_namespace = 'sagemaker-training-containers/'
# prefix = 'tf-script-mode-container-2'

# ecr_repository_name = ecr_namespace + prefix
# role = get_execution_role()
# account_id = role.split(':')[4]
# region = boto3.Session().region_name
# sagemaker_session = sagemaker.session.Session()
# bucket = sagemaker_session.default_bucket()

# print(account_id)
# print(region)
# print(role)
# print(bucket)

# %%
import os
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()
sagemaker_session = sagemaker.session.Session()
bucket = sagemaker_session.default_bucket()
prefix = 'byoc-cifar10'

# %% [markdown]
# ## 로컬의 데이터 S3 업로딩
# 로컬의 데이터를 S3에 업로딩하여 훈련시에 Input으로 사용 합니다.

# %%
dataset_location = sagemaker_session.upload_data(path='data', key_prefix='data/DEMO-cifar10')
display(dataset_location)
# Out:
# 's3://sagemaker-ap-northeast-2-057716757052/data/DEMO-cifar10'

# %%
# %store -r container_image_uri
print (container_image_uri)
# Out:
# 057716757052.dkr.ecr.ap-northeast-2.amazonaws.com/sagemaker-training-containers/tf-script-mode-container-2:latest

# %%
train_code_file = 'cifar10_keras_sm_tf2.py'

# %% [markdown]
# <h3>Training with a custom SDK framework estimator</h3>

# %% [markdown]
# As you have seen, in the previous steps we had to upload our code to Amazon S3 and then inject reserved hyperparameters to execute training. In order to facilitate this task, you can also try defining a custom framework estimator using the Amazon SageMaker Python SDK and run training with that class, which will take care of managing these tasks.

# %%
from sagemaker.estimator import Framework

class CustomFramework(Framework):
    def __init__(
        self,
        entry_point,
        source_dir=None,
        hyperparameters=None,
        py_version="py3",
        framework_version=None,
        image_name=None,
        distributions=None,
        **kwargs
    ):
        super(CustomFramework, self).__init__(
            entry_point, source_dir, hyperparameters, image_name=image_name, **kwargs
        )
    
    def _configure_distribution(self, distributions):
        return
    
    def create_model(
        self,
        model_server_workers=None,
        role=None,
        vpc_config_override=None,
        entry_point=None,
        source_dir=None,
        dependencies=None,
        image_name=None,
        **kwargs
    ):
        return None
        
import sagemaker

est = CustomFramework(image_name=container_image_uri,
                      entry_point=train_code_file,
                      source_dir='source_dir/',
                      role=role,
                      train_instance_count=1, 
                      train_instance_type='local', # we use local mode
                      #train_instance_type='ml.m5.xlarge',
                      base_job_name='byoc-cifar10',
                      hyperparameters={'epochs': "1", 
                                       'model_dir' : './logs'
                                      },                      
                        )

# train_config = sagemaker.session.s3_input('s3://{0}/{1}/train/'.format(bucket, prefix), content_type='text/csv')
# val_config = sagemaker.session.s3_input('s3://{0}/{1}/val/'.format(bucket, prefix), content_type='text/csv')

# est.fit({'train': train_config, 'validation': val_config })

est.fit({'train':'{}/train'.format(dataset_location),
              'validation':'{}/validation'.format(dataset_location),
              'eval':'{}/eval'.format(dataset_location)})
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# image_name has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Building with native build. Learn about native build in Compose here: https://docs.docker.com/go/compose-native-build/
# Creating z8qbmpgrj6-algo-1-yuqh4 ...
# Creating z8qbmpgrj6-algo-1-yuqh4 ... done
# Attaching to z8qbmpgrj6-algo-1-yuqh4
# z8qbmpgrj6-algo-1-yuqh4 | 2021-02-25 11:43:31,794 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# z8qbmpgrj6-algo-1-yuqh4 | /usr/bin/python3 -m pip install -r requirements.txt
# z8qbmpgrj6-algo-1-yuqh4 | /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
# z8qbmpgrj6-algo-1-yuqh4 |   from cryptography.utils import int_from_bytes
# z8qbmpgrj6-algo-1-yuqh4 | /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
# z8qbmpgrj6-algo-1-yuqh4 |   from cryptography.utils import int_from_bytes
# z8qbmpgrj6-algo-1-yuqh4 | Collecting pandas<2
# z8qbmpgrj6-algo-1-yuqh4 |   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 2.6 MB/s eta 0:00:01
# z8qbmpgrj6-algo-1-yuqh4 | Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (2.8.1)
# z8qbmpgrj6-algo-1-yuqh4 | Collecting pytz>=2017.2
# z8qbmpgrj6-algo-1-yuqh4 |   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 37.6 MB/s eta 0:00:01
# z8qbmpgrj6-algo-1-yuqh4 | Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (1.18.2)
# z8qbmpgrj6-algo-1-yuqh4 | Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas<2->-r requirements.txt (line 1)) (1.14.0)
# z8qbmpgrj6-algo-1-yuqh4 | Installing collected packages: pytz, pandas
# z8qbmpgrj6-algo-1-yuqh4 | Successfully installed pandas-1.1.5 pytz-2021.1
# z8qbmpgrj6-algo-1-yuqh4 | WARNING: You are using pip version 20.0.2; however, version 21.0.1 is available.
# z8qbmpgrj6-algo-1-yuqh4 | You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# z8qbmpgrj6-algo-1-yuqh4 | 2021-02-25 11:43:37,165 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# z8qbmpgrj6-algo-1-yuqh4 | 2021-02-25 11:43:37,175 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# z8qbmpgrj6-algo-1-yuqh4 | 2021-02-25 11:43:37,184 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# z8qbmpgrj6-algo-1-yuqh4 | 2021-02-25 11:43:37,194 sagemaker-training-toolkit INFO     Invoking user script
# z8qbmpgrj6-algo-1-yuqh4 |
# z8qbmpgrj6-algo-1-yuqh4 | Training Env:
# z8qbmpgrj6-algo-1-yuqh4 |
# z8qbmpgrj6-algo-1-yuqh4 | {
# z8qbmpgrj6-algo-1-yuqh4 |     "additional_framework_parameters": {},
# z8qbmpgrj6-algo-1-yuqh4 |     "channel_input_dirs": {
# z8qbmpgrj6-algo-1-yuqh4 |         "train": "/opt/ml/input/data/train",
# z8qbmpgrj6-algo-1-yuqh4 |         "validation": "/opt/ml/input/data/validation",
# z8qbmpgrj6-algo-1-yuqh4 |         "eval": "/opt/ml/input/data/eval"
# z8qbmpgrj6-algo-1-yuqh4 |     },
# z8qbmpgrj6-algo-1-yuqh4 |     "current_host": "algo-1-yuqh4",
# z8qbmpgrj6-algo-1-yuqh4 |     "framework_module": null,
# z8qbmpgrj6-algo-1-yuqh4 |     "hosts": [
# z8qbmpgrj6-algo-1-yuqh4 |         "algo-1-yuqh4"
# z8qbmpgrj6-algo-1-yuqh4 |     ],
# z8qbmpgrj6-algo-1-yuqh4 |     "hyperparameters": {
# z8qbmpgrj6-algo-1-yuqh4 |         "epochs": "1",
# z8qbmpgrj6-algo-1-yuqh4 |         "model_dir": "./logs"
# z8qbmpgrj6-algo-1-yuqh4 |     },
# z8qbmpgrj6-algo-1-yuqh4 |     "input_config_dir": "/opt/ml/input/config",
# z8qbmpgrj6-algo-1-yuqh4 |     "input_data_config": {
# z8qbmpgrj6-algo-1-yuqh4 |         "train": {
# z8qbmpgrj6-algo-1-yuqh4 |             "TrainingInputMode": "File"
# z8qbmpgrj6-algo-1-yuqh4 |         },
# z8qbmpgrj6-algo-1-yuqh4 |         "validation": {
# z8qbmpgrj6-algo-1-yuqh4 |             "TrainingInputMode": "File"
# z8qbmpgrj6-algo-1-yuqh4 |         },
# z8qbmpgrj6-algo-1-yuqh4 |         "eval": {
# z8qbmpgrj6-algo-1-yuqh4 |             "TrainingInputMode": "File"
# z8qbmpgrj6-algo-1-yuqh4 |         }
# z8qbmpgrj6-algo-1-yuqh4 |     },
# z8qbmpgrj6-algo-1-yuqh4 |     "input_dir": "/opt/ml/input",
# z8qbmpgrj6-algo-1-yuqh4 |     "is_master": true,
# z8qbmpgrj6-algo-1-yuqh4 |     "job_name": "byoc-cifar10-2021-02-25-11-43-28-469",
# z8qbmpgrj6-algo-1-yuqh4 |     "log_level": 20,
# z8qbmpgrj6-algo-1-yuqh4 |     "master_hostname": "algo-1-yuqh4",
# z8qbmpgrj6-algo-1-yuqh4 |     "model_dir": "/opt/ml/model",
# z8qbmpgrj6-algo-1-yuqh4 |     "module_dir": "s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10-2021-02-25-11-43-28-469/source/sourcedir.tar.gz",
# z8qbmpgrj6-algo-1-yuqh4 |     "module_name": "cifar10_keras_sm_tf2",
# z8qbmpgrj6-algo-1-yuqh4 |     "network_interface_name": "eth0",
# z8qbmpgrj6-algo-1-yuqh4 |     "num_cpus": 36,
# z8qbmpgrj6-algo-1-yuqh4 |     "num_gpus": 0,
# z8qbmpgrj6-algo-1-yuqh4 |     "output_data_dir": "/opt/ml/output/data",
# z8qbmpgrj6-algo-1-yuqh4 |     "output_dir": "/opt/ml/output",
# z8qbmpgrj6-algo-1-yuqh4 |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# z8qbmpgrj6-algo-1-yuqh4 |     "resource_config": {
# z8qbmpgrj6-algo-1-yuqh4 |         "current_host": "algo-1-yuqh4",
# z8qbmpgrj6-algo-1-yuqh4 |         "hosts": [
# z8qbmpgrj6-algo-1-yuqh4 |             "algo-1-yuqh4"
# z8qbmpgrj6-algo-1-yuqh4 |         ]
# z8qbmpgrj6-algo-1-yuqh4 |     },
# z8qbmpgrj6-algo-1-yuqh4 |     "user_entry_point": "cifar10_keras_sm_tf2.py"
# z8qbmpgrj6-algo-1-yuqh4 | }
# z8qbmpgrj6-algo-1-yuqh4 |
# z8qbmpgrj6-algo-1-yuqh4 | Environment variables:
# z8qbmpgrj6-algo-1-yuqh4 |
# z8qbmpgrj6-algo-1-yuqh4 | SM_HOSTS=["algo-1-yuqh4"]
# z8qbmpgrj6-algo-1-yuqh4 | SM_NETWORK_INTERFACE_NAME=eth0
# z8qbmpgrj6-algo-1-yuqh4 | SM_HPS={"epochs":"1","model_dir":"./logs"}
# z8qbmpgrj6-algo-1-yuqh4 | SM_USER_ENTRY_POINT=cifar10_keras_sm_tf2.py
# z8qbmpgrj6-algo-1-yuqh4 | SM_FRAMEWORK_PARAMS={}
# z8qbmpgrj6-algo-1-yuqh4 | SM_RESOURCE_CONFIG={"current_host":"algo-1-yuqh4","hosts":["algo-1-yuqh4"]}
# z8qbmpgrj6-algo-1-yuqh4 | SM_INPUT_DATA_CONFIG={"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}}
# z8qbmpgrj6-algo-1-yuqh4 | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# z8qbmpgrj6-algo-1-yuqh4 | SM_CHANNELS=["eval","train","validation"]
# z8qbmpgrj6-algo-1-yuqh4 | SM_CURRENT_HOST=algo-1-yuqh4
# z8qbmpgrj6-algo-1-yuqh4 | SM_MODULE_NAME=cifar10_keras_sm_tf2
# z8qbmpgrj6-algo-1-yuqh4 | SM_LOG_LEVEL=20
# z8qbmpgrj6-algo-1-yuqh4 | SM_FRAMEWORK_MODULE=
# z8qbmpgrj6-algo-1-yuqh4 | SM_INPUT_DIR=/opt/ml/input
# z8qbmpgrj6-algo-1-yuqh4 | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# z8qbmpgrj6-algo-1-yuqh4 | SM_OUTPUT_DIR=/opt/ml/output
# z8qbmpgrj6-algo-1-yuqh4 | SM_NUM_CPUS=36
# z8qbmpgrj6-algo-1-yuqh4 | SM_NUM_GPUS=0
# z8qbmpgrj6-algo-1-yuqh4 | SM_MODEL_DIR=/opt/ml/model
# z8qbmpgrj6-algo-1-yuqh4 | SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10-2021-02-25-11-43-28-469/source/sourcedir.tar.gz
# z8qbmpgrj6-algo-1-yuqh4 | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1-yuqh4","framework_module":null,"hosts":["algo-1-yuqh4"],"hyperparameters":{"epochs":"1","model_dir":"./logs"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"byoc-cifar10-2021-02-25-11-43-28-469","log_level":20,"master_hostname":"algo-1-yuqh4","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10-2021-02-25-11-43-28-469/source/sourcedir.tar.gz","module_name":"cifar10_keras_sm_tf2","network_interface_name":"eth0","num_cpus":36,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-yuqh4","hosts":["algo-1-yuqh4"]},"user_entry_point":"cifar10_keras_sm_tf2.py"}
# z8qbmpgrj6-algo-1-yuqh4 | SM_USER_ARGS=["--epochs","1","--model_dir","./logs"]
# z8qbmpgrj6-algo-1-yuqh4 | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# z8qbmpgrj6-algo-1-yuqh4 | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# z8qbmpgrj6-algo-1-yuqh4 | SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# z8qbmpgrj6-algo-1-yuqh4 | SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# z8qbmpgrj6-algo-1-yuqh4 | SM_HP_EPOCHS=1
# z8qbmpgrj6-algo-1-yuqh4 | SM_HP_MODEL_DIR=./logs
# z8qbmpgrj6-algo-1-yuqh4 | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# z8qbmpgrj6-algo-1-yuqh4 |
# z8qbmpgrj6-algo-1-yuqh4 | Invoking script with the following command:
# z8qbmpgrj6-algo-1-yuqh4 |
# z8qbmpgrj6-algo-1-yuqh4 | /usr/bin/python3 cifar10_keras_sm_tf2.py --epochs 1 --model_dir ./logs
# z8qbmpgrj6-algo-1-yuqh4 |
# z8qbmpgrj6-algo-1-yuqh4 |
# z8qbmpgrj6-algo-1-yuqh4 | 2021-02-25 11:43:38.603921: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# z8qbmpgrj6-algo-1-yuqh4 | 2021-02-25 11:43:38.603948: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: UNKNOWN ERROR (-1)
# z8qbmpgrj6-algo-1-yuqh4 | 2021-02-25 11:43:38.603964: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (991a9a484389): /proc/driver/nvidia/version does not exist
# z8qbmpgrj6-algo-1-yuqh4 | 2021-02-25 11:43:38.604206: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# z8qbmpgrj6-algo-1-yuqh4 | 2021-02-25 11:43:38.629021: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 3000000000 Hz
# z8qbmpgrj6-algo-1-yuqh4 | 2021-02-25 11:43:38.630716: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f9394000b20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# z8qbmpgrj6-algo-1-yuqh4 | 2021-02-25 11:43:38.630739: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 312/312 [==============================] - 19s 61ms/step - loss: 1.8332 - accuracy: 0.3247 - val_loss: 2.2009 - val_accuracy: 0.2741
# z8qbmpgrj6-algo-1-yuqh4 | 2021-02-25 11:44:01.647432: W tensorflow/python/util/util.cc:329] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# z8qbmpgrj6-algo-1-yuqh4 | WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# z8qbmpgrj6-algo-1-yuqh4 | Instructions for updating:
# z8qbmpgrj6-algo-1-yuqh4 | If using Keras pass *_constraint arguments to layers.
# z8qbmpgrj6-algo-1-yuqh4 | WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# z8qbmpgrj6-algo-1-yuqh4 | Instructions for updating:
# z8qbmpgrj6-algo-1-yuqh4 | If using Keras pass *_constraint arguments to layers.
# z8qbmpgrj6-algo-1-yuqh4 | INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# z8qbmpgrj6-algo-1-yuqh4 | INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# z8qbmpgrj6-algo-1-yuqh4 | 2021-02-25 11:44:03,493 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# z8qbmpgrj6-algo-1-yuqh4 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %% [markdown]
# ## S3 Code에서 실행
#
# 현재의 training_job_name을 저장 합니다.
# - training_job_name을 에는 훈련에 관련 내용 및 훈련 결과인 **Model Artifact** 파일의 S3 경로를 제공 합니다.

# %%
import tarfile
import os

def create_tar_file(source_files, target=None):
    if target:
        filename = target
    else:
        _, filename = tempfile.mkstemp()

    with tarfile.open(filename, mode="w:gz") as t:
        for sf in source_files:
            # Add all files from the directory into the root of the directory structure of the tar
            t.add(sf, arcname=os.path.basename(sf))
    return filename

create_tar_file(["source_dir/cifar10_keras_sm_tf2.py", "source_dir/requirements.txt"], "sourcedir.tar.gz")
# Out:
# 'sourcedir.tar.gz'

# %%
sources = sagemaker_session.upload_data('sourcedir.tar.gz', bucket, prefix + '/code')
print(sources)
! rm sourcedir.tar.gz
# Out:
# s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz

# %% [markdown]
# When starting the training job, we need to let the sagemaker-training-toolkit library know where the sources are stored in Amazon S3 and what is the module to be invoked. These parameters are specified through the following reserved hyperparameters (these reserved hyperparameters are injected automatically when using framework estimators of the Amazon SageMaker Python SDK):
# <ul>
#     <li>sagemaker_program</li>
#     <li>sagemaker_submit_directory</li>
# </ul>
#
# Finally, we can execute the training job by calling the fit() method of the generic Estimator object defined in the Amazon SageMaker Python SDK (https://github.com/aws/sagemaker-python-sdk/blob/master/src/sagemaker/estimator.py). This corresponds to calling the CreateTrainingJob() API (https://docs.aws.amazon.com/sagemaker/latest/dg/API_CreateTrainingJob.html).

# %%
import sagemaker
import json
# JSON encode hyperparameters.
def json_encode_hyperparameters(hyperparameters):
    return {str(k): json.dumps(v) for (k, v) in hyperparameters.items()}

hyperparameters = json_encode_hyperparameters({
    "sagemaker_program": train_code_file,
    "sagemaker_submit_directory": sources,
    'epochs': "1", 
    'model_dir' : './logs'    
    })

hyperparameters
# Out:
# {'sagemaker_program': '"cifar10_keras_sm_tf2.py"',
#  'sagemaker_submit_directory': '"s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz"',
#  'epochs': '"1"',
#  'model_dir': '"./logs"'}

# %%
est = sagemaker.estimator.Estimator(container_image_uri,
                                    role,
                                    train_instance_count=1, 
                                    train_instance_type='local',
                                    base_job_name=prefix,
                                    hyperparameters=hyperparameters)

# train_config = sagemaker.session.s3_input('s3://{0}/{1}/train/'.format(bucket, prefix), content_type='text/csv')
# val_config = sagemaker.session.s3_input('s3://{0}/{1}/val/'.format(bucket, prefix), content_type='text/csv')

# est.fit({'train': train_config, 'validation': val_config })

est.fit({'train':'{}/train'.format(dataset_location),
              'validation':'{}/validation'.format(dataset_location),
              'eval':'{}/eval'.format(dataset_location)})
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Building with native build. Learn about native build in Compose here: https://docs.docker.com/go/compose-native-build/
# Creating xtn3in2wip-algo-1-qqfo4 ...
# Creating xtn3in2wip-algo-1-qqfo4 ... done
# Attaching to xtn3in2wip-algo-1-qqfo4
# xtn3in2wip-algo-1-qqfo4 | 2021-02-25 12:01:22,647 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# xtn3in2wip-algo-1-qqfo4 | /usr/bin/python3 -m pip install -r requirements.txt
# xtn3in2wip-algo-1-qqfo4 | /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
# xtn3in2wip-algo-1-qqfo4 |   from cryptography.utils import int_from_bytes
# xtn3in2wip-algo-1-qqfo4 | /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
# xtn3in2wip-algo-1-qqfo4 |   from cryptography.utils import int_from_bytes
# xtn3in2wip-algo-1-qqfo4 | Collecting pandas<2
# xtn3in2wip-algo-1-qqfo4 |   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 2.4 MB/s eta 0:00:01
# xtn3in2wip-algo-1-qqfo4 | Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (1.18.2)
# xtn3in2wip-algo-1-qqfo4 | Collecting pytz>=2017.2
# xtn3in2wip-algo-1-qqfo4 |   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 29.4 MB/s eta 0:00:01
# xtn3in2wip-algo-1-qqfo4 | Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (2.8.1)
# xtn3in2wip-algo-1-qqfo4 | Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas<2->-r requirements.txt (line 1)) (1.14.0)
# xtn3in2wip-algo-1-qqfo4 | Installing collected packages: pytz, pandas
# xtn3in2wip-algo-1-qqfo4 | Successfully installed pandas-1.1.5 pytz-2021.1
# xtn3in2wip-algo-1-qqfo4 | WARNING: You are using pip version 20.0.2; however, version 21.0.1 is available.
# xtn3in2wip-algo-1-qqfo4 | You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# xtn3in2wip-algo-1-qqfo4 | 2021-02-25 12:01:28,132 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# xtn3in2wip-algo-1-qqfo4 | 2021-02-25 12:01:28,142 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# xtn3in2wip-algo-1-qqfo4 | 2021-02-25 12:01:28,151 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# xtn3in2wip-algo-1-qqfo4 | 2021-02-25 12:01:28,161 sagemaker-training-toolkit INFO     Invoking user script
# xtn3in2wip-algo-1-qqfo4 |
# xtn3in2wip-algo-1-qqfo4 | Training Env:
# xtn3in2wip-algo-1-qqfo4 |
# xtn3in2wip-algo-1-qqfo4 | {
# xtn3in2wip-algo-1-qqfo4 |     "additional_framework_parameters": {},
# xtn3in2wip-algo-1-qqfo4 |     "channel_input_dirs": {
# xtn3in2wip-algo-1-qqfo4 |         "train": "/opt/ml/input/data/train",
# xtn3in2wip-algo-1-qqfo4 |         "validation": "/opt/ml/input/data/validation",
# xtn3in2wip-algo-1-qqfo4 |         "eval": "/opt/ml/input/data/eval"
# xtn3in2wip-algo-1-qqfo4 |     },
# xtn3in2wip-algo-1-qqfo4 |     "current_host": "algo-1-qqfo4",
# xtn3in2wip-algo-1-qqfo4 |     "framework_module": null,
# xtn3in2wip-algo-1-qqfo4 |     "hosts": [
# xtn3in2wip-algo-1-qqfo4 |         "algo-1-qqfo4"
# xtn3in2wip-algo-1-qqfo4 |     ],
# xtn3in2wip-algo-1-qqfo4 |     "hyperparameters": {
# xtn3in2wip-algo-1-qqfo4 |         "epochs": "1",
# xtn3in2wip-algo-1-qqfo4 |         "model_dir": "./logs"
# xtn3in2wip-algo-1-qqfo4 |     },
# xtn3in2wip-algo-1-qqfo4 |     "input_config_dir": "/opt/ml/input/config",
# xtn3in2wip-algo-1-qqfo4 |     "input_data_config": {
# xtn3in2wip-algo-1-qqfo4 |         "train": {
# xtn3in2wip-algo-1-qqfo4 |             "TrainingInputMode": "File"
# xtn3in2wip-algo-1-qqfo4 |         },
# xtn3in2wip-algo-1-qqfo4 |         "validation": {
# xtn3in2wip-algo-1-qqfo4 |             "TrainingInputMode": "File"
# xtn3in2wip-algo-1-qqfo4 |         },
# xtn3in2wip-algo-1-qqfo4 |         "eval": {
# xtn3in2wip-algo-1-qqfo4 |             "TrainingInputMode": "File"
# xtn3in2wip-algo-1-qqfo4 |         }
# xtn3in2wip-algo-1-qqfo4 |     },
# xtn3in2wip-algo-1-qqfo4 |     "input_dir": "/opt/ml/input",
# xtn3in2wip-algo-1-qqfo4 |     "is_master": true,
# xtn3in2wip-algo-1-qqfo4 |     "job_name": "byoc-cifar10-2021-02-25-12-01-19-287",
# xtn3in2wip-algo-1-qqfo4 |     "log_level": 20,
# xtn3in2wip-algo-1-qqfo4 |     "master_hostname": "algo-1-qqfo4",
# xtn3in2wip-algo-1-qqfo4 |     "model_dir": "/opt/ml/model",
# xtn3in2wip-algo-1-qqfo4 |     "module_dir": "s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz",
# xtn3in2wip-algo-1-qqfo4 |     "module_name": "cifar10_keras_sm_tf2",
# xtn3in2wip-algo-1-qqfo4 |     "network_interface_name": "eth0",
# xtn3in2wip-algo-1-qqfo4 |     "num_cpus": 36,
# xtn3in2wip-algo-1-qqfo4 |     "num_gpus": 0,
# xtn3in2wip-algo-1-qqfo4 |     "output_data_dir": "/opt/ml/output/data",
# xtn3in2wip-algo-1-qqfo4 |     "output_dir": "/opt/ml/output",
# xtn3in2wip-algo-1-qqfo4 |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# xtn3in2wip-algo-1-qqfo4 |     "resource_config": {
# xtn3in2wip-algo-1-qqfo4 |         "current_host": "algo-1-qqfo4",
# xtn3in2wip-algo-1-qqfo4 |         "hosts": [
# xtn3in2wip-algo-1-qqfo4 |             "algo-1-qqfo4"
# xtn3in2wip-algo-1-qqfo4 |         ]
# xtn3in2wip-algo-1-qqfo4 |     },
# xtn3in2wip-algo-1-qqfo4 |     "user_entry_point": "cifar10_keras_sm_tf2.py"
# xtn3in2wip-algo-1-qqfo4 | }
# xtn3in2wip-algo-1-qqfo4 |
# xtn3in2wip-algo-1-qqfo4 | Environment variables:
# xtn3in2wip-algo-1-qqfo4 |
# xtn3in2wip-algo-1-qqfo4 | SM_HOSTS=["algo-1-qqfo4"]
# xtn3in2wip-algo-1-qqfo4 | SM_NETWORK_INTERFACE_NAME=eth0
# xtn3in2wip-algo-1-qqfo4 | SM_HPS={"epochs":"1","model_dir":"./logs"}
# xtn3in2wip-algo-1-qqfo4 | SM_USER_ENTRY_POINT=cifar10_keras_sm_tf2.py
# xtn3in2wip-algo-1-qqfo4 | SM_FRAMEWORK_PARAMS={}
# xtn3in2wip-algo-1-qqfo4 | SM_RESOURCE_CONFIG={"current_host":"algo-1-qqfo4","hosts":["algo-1-qqfo4"]}
# xtn3in2wip-algo-1-qqfo4 | SM_INPUT_DATA_CONFIG={"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}}
# xtn3in2wip-algo-1-qqfo4 | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# xtn3in2wip-algo-1-qqfo4 | SM_CHANNELS=["eval","train","validation"]
# xtn3in2wip-algo-1-qqfo4 | SM_CURRENT_HOST=algo-1-qqfo4
# xtn3in2wip-algo-1-qqfo4 | SM_MODULE_NAME=cifar10_keras_sm_tf2
# xtn3in2wip-algo-1-qqfo4 | SM_LOG_LEVEL=20
# xtn3in2wip-algo-1-qqfo4 | SM_FRAMEWORK_MODULE=
# xtn3in2wip-algo-1-qqfo4 | SM_INPUT_DIR=/opt/ml/input
# xtn3in2wip-algo-1-qqfo4 | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# xtn3in2wip-algo-1-qqfo4 | SM_OUTPUT_DIR=/opt/ml/output
# xtn3in2wip-algo-1-qqfo4 | SM_NUM_CPUS=36
# xtn3in2wip-algo-1-qqfo4 | SM_NUM_GPUS=0
# xtn3in2wip-algo-1-qqfo4 | SM_MODEL_DIR=/opt/ml/model
# xtn3in2wip-algo-1-qqfo4 | SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz
# xtn3in2wip-algo-1-qqfo4 | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1-qqfo4","framework_module":null,"hosts":["algo-1-qqfo4"],"hyperparameters":{"epochs":"1","model_dir":"./logs"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"byoc-cifar10-2021-02-25-12-01-19-287","log_level":20,"master_hostname":"algo-1-qqfo4","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz","module_name":"cifar10_keras_sm_tf2","network_interface_name":"eth0","num_cpus":36,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-qqfo4","hosts":["algo-1-qqfo4"]},"user_entry_point":"cifar10_keras_sm_tf2.py"}
# xtn3in2wip-algo-1-qqfo4 | SM_USER_ARGS=["--epochs","1","--model_dir","./logs"]
# xtn3in2wip-algo-1-qqfo4 | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# xtn3in2wip-algo-1-qqfo4 | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# xtn3in2wip-algo-1-qqfo4 | SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# xtn3in2wip-algo-1-qqfo4 | SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# xtn3in2wip-algo-1-qqfo4 | SM_HP_EPOCHS=1
# xtn3in2wip-algo-1-qqfo4 | SM_HP_MODEL_DIR=./logs
# xtn3in2wip-algo-1-qqfo4 | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# xtn3in2wip-algo-1-qqfo4 |
# xtn3in2wip-algo-1-qqfo4 | Invoking script with the following command:
# xtn3in2wip-algo-1-qqfo4 |
# xtn3in2wip-algo-1-qqfo4 | /usr/bin/python3 cifar10_keras_sm_tf2.py --epochs 1 --model_dir ./logs
# xtn3in2wip-algo-1-qqfo4 |
# xtn3in2wip-algo-1-qqfo4 |
# xtn3in2wip-algo-1-qqfo4 | 2021-02-25 12:01:29.598522: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# xtn3in2wip-algo-1-qqfo4 | 2021-02-25 12:01:29.598548: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: UNKNOWN ERROR (-1)
# xtn3in2wip-algo-1-qqfo4 | 2021-02-25 12:01:29.598564: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (38f35738d5c3): /proc/driver/nvidia/version does not exist
# xtn3in2wip-algo-1-qqfo4 | 2021-02-25 12:01:29.598796: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# xtn3in2wip-algo-1-qqfo4 | 2021-02-25 12:01:29.624886: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 3000000000 Hz
# xtn3in2wip-algo-1-qqfo4 | 2021-02-25 12:01:29.627080: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f0dec000b20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# xtn3in2wip-algo-1-qqfo4 | 2021-02-25 12:01:29.627097: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 312/312 [==============================] - 19s 62ms/step - loss: 1.8232 - accuracy: 0.3237 - val_loss: 1.8625 - val_accuracy: 0.3230
# xtn3in2wip-algo-1-qqfo4 | 2021-02-25 12:01:52.859319: W tensorflow/python/util/util.cc:329] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# xtn3in2wip-algo-1-qqfo4 | WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# xtn3in2wip-algo-1-qqfo4 | Instructions for updating:
# xtn3in2wip-algo-1-qqfo4 | If using Keras pass *_constraint arguments to layers.
# xtn3in2wip-algo-1-qqfo4 | WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# xtn3in2wip-algo-1-qqfo4 | Instructions for updating:
# xtn3in2wip-algo-1-qqfo4 | If using Keras pass *_constraint arguments to layers.
# xtn3in2wip-algo-1-qqfo4 | INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# xtn3in2wip-algo-1-qqfo4 | INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# xtn3in2wip-algo-1-qqfo4 | 2021-02-25 12:01:54,687 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# xtn3in2wip-algo-1-qqfo4 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %% [markdown]
# ## 사용자 정의 컨테이너로 SageMaker Cloud 에서 학습

# %%
est = sagemaker.estimator.Estimator(container_image_uri, # 사용자 정의 컨테이너
                                    role,
                                    train_instance_count=1, 
                                    train_instance_type='ml.p2.xlarge',
                                    base_job_name=prefix,
                                    hyperparameters=hyperparameters)

est.fit({'train':'{}/train'.format(dataset_location),
              'validation':'{}/validation'.format(dataset_location),
              'eval':'{}/eval'.format(dataset_location)})
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2021-02-25 12:03:51 Starting - Starting the training job...
# 2021-02-25 12:04:15 Starting - Launching requested ML instancesProfilerReport-1614254631: InProgress
# ......
# 2021-02-25 12:05:16 Starting - Preparing the instances for training......
# 2021-02-25 12:06:17 Downloading - Downloading input data...
# 2021-02-25 12:06:37 Training - Downloading the training image...........2021-02-25 12:08:32,555 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /usr/bin/python3 -m pip install -r requirements.txt
# /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting pandas<2
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting pytz>=2017.2
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (1.18.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas<2->-r requirements.txt (line 1)) (1.14.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.1.5 pytz-2021.1
# WARNING: You are using pip version 20.0.2; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# 2021-02-25 12:08:40,376 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "validation": "/opt/ml/input/data/validation",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": null,
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "model_dir": "./logs",
#         "epochs": "1"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "byoc-cifar10-2021-02-25-12-03-51-043",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz",
#     "module_name": "cifar10_keras_sm_tf2",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "cifar10_keras_sm_tf2.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":"1","model_dir":"./logs"}
# SM_USER_ENTRY_POINT=cifar10_keras_sm_tf2.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=cifar10_keras_sm_tf2
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":null,"hosts":["algo-1"],"hyperparameters":{"epochs":"1","model_dir":"./logs"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"byoc-cifar10-2021-02-25-12-03-51-043","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz","module_name":"cifar10_keras_sm_tf2","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"cifar10_keras_sm_tf2.py"}
# SM_USER_ARGS=["--epochs","1","--model_dir","./logs"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_DIR=./logs
# SM_HP_EPOCHS=1
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 cifar10_keras_sm_tf2.py --epochs 1 --model_dir ./logs
#
#
#
# 2021-02-25 12:08:38 Training - Training image download completed. Training in progress.2021-02-25 12:08:44.457608: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-02-25 12:08:44.620401: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:08:44.621296: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8755GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2021-02-25 12:08:44.624981: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-25 12:08:44.724722: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-02-25 12:08:44.778788: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-02-25 12:08:44.790668: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-02-25 12:08:44.892856: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-02-25 12:08:44.910489: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-02-25 12:08:45.093059: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-02-25 12:08:45.093288: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:08:45.094309: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:08:45.095093: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-02-25 12:08:45.096244: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-02-25 12:08:45.111918: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300030000 Hz
# 2021-02-25 12:08:45.112308: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fd78c000b20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-02-25 12:08:45.112341: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-02-25 12:08:45.363226: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:08:45.364137: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5d05ac0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-02-25 12:08:45.364168: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2021-02-25 12:08:45.365996: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:08:45.366786: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8755GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2021-02-25 12:08:45.366847: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-25 12:08:45.366877: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-02-25 12:08:45.366907: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-02-25 12:08:45.366950: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-02-25 12:08:45.366981: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-02-25 12:08:45.367012: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-02-25 12:08:45.367039: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-02-25 12:08:45.367131: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:08:45.367929: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:08:45.368679: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-02-25 12:08:45.369489: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-25 12:08:45.372534: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-02-25 12:08:45.372563: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2021-02-25 12:08:45.372576: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2021-02-25 12:08:45.373587: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:08:45.374423: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:08:45.375236: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10699 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0, compute capability: 3.7)
# 2021-02-25 12:08:49.714031: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-02-25 12:08:52.513311: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# #015  1/312 [..............................] - ETA: 0s - loss: 4.1043 - accuracy: 0.0703#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  3/312 [..............................] - ETA: 6s - loss: 3.8703 - accuracy: 0.0729#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  5/312 [..............................] - ETA: 7s - loss: 3.6755 - accuracy: 0.0891#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  7/312 [..............................] - ETA: 7s - loss: 3.4279 - accuracy: 0.1027#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  9/312 [..............................] - ETA: 7s - loss: 3.2546 - accuracy: 0.1146#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 11/312 [>.............................] - ETA: 8s - loss: 3.1451 - accuracy: 0.1286#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 13/312 [>.............................] - ETA: 8s - loss: 3.0388 - accuracy: 0.1400#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 15/312 [>.............................] - ETA: 8s - loss: 2.9368 - accuracy: 0.1490#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 17/312 [>.............................] - ETA: 8s - loss: 2.8649 - accuracy: 0.1540#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 19/312 [>.............................] - ETA: 8s - loss: 2.8078 - accuracy: 0.1604#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010 ...
# #010#010#010#010#010#010#010#010#010#015195/312 [=================>............] - ETA: 3s - loss: 1.9549 - accuracy: 0.2837#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015197/312 [=================>............] - ETA: 3s - loss: 1.9525 - accuracy: 0.2846#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015199/312 [==================>...........] - ETA: 3s - loss: 1.9495 - accuracy: 0.2857#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015201/312 [==================>...........] - ETA: 3s - loss: 1.9472 - accuracy: 0.2863#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015203/312 [==================>...........] - ETA: 3s - loss: 1.9441 - accuracy: 0.2871#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015205/312 [==================>...........] - ETA: 3s - loss: 1.9407 - accuracy: 0.2886#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015207/312 [==================>...........] - ETA: 3s - loss: 1.9391 - accuracy: 0.2888#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015209/312 [===================>..........] - ETA: 3s - loss: 1.9368 - accuracy: 0.2890#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015211/312 [===================>..........] - ETA: 2s - loss: 1.9338 - accuracy: 0.2899#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015213/312 [===================>..........] - ETA: 2s - loss: 1.9312 - accuracy: 0.2906#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010 ...
# 2021-02-25 12:09:09.598621: W tensorflow/python/util/util.cc:329] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
#
# 2021-02-25 12:09:20 Uploading - Uploading generated training model
# 2021-02-25 12:09:20 Completed - Training job completed
# INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# 2021-02-25 12:09:12,984 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Training seconds: 187
# Billable seconds: 187

# %%
train_job_name = estimator._current_job_name

# %%
# %store train_job_name
# Out:
# Stored 'train_job_name' (str)
