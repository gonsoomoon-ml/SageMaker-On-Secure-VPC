# %% [markdown]
# # [모듈 3.1] 사용자 정의 컨테이너로 학습
#
# ---

# %% [markdown]
# SageMaker의 세션을 얻고, role 정보를 가져옵니다.
# - 위의 두 정보를 통해서 SageMaker Hosting Cluster에 연결합니다.

# %%
import os
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()
sagemaker_session = sagemaker.session.Session()
bucket = sagemaker_session.default_bucket()
prefix = 'byoc-cifar10'

# %% [markdown]
# ## 로컬의 데이터 S3 업로딩
# 로컬의 데이터를 S3에 업로딩하여 훈련시에 Input으로 사용 합니다.

# %%
dataset_location = sagemaker_session.upload_data(path='data', key_prefix='data/DEMO-cifar10')
display(dataset_location)
# Out:
# 's3://sagemaker-ap-northeast-2-057716757052/data/DEMO-cifar10'

# %%
# %store -r container_image_uri
print (container_image_uri)
# Out:
# 057716757052.dkr.ecr.ap-northeast-2.amazonaws.com/sagemaker-training-containers/tf-script-mode-container-2:latest

# %%
train_code_file = 'cifar10_keras_sm_tf2.py'

# %% [markdown]
# <h3>Training with a custom SDK framework estimator</h3>

# %% [markdown]
# As you have seen, in the previous steps we had to upload our code to Amazon S3 and then inject reserved hyperparameters to execute training. In order to facilitate this task, you can also try defining a custom framework estimator using the Amazon SageMaker Python SDK and run training with that class, which will take care of managing these tasks.

# %%
from sagemaker.estimator import Framework

class CustomFramework(Framework):
    def __init__(
        self,
        entry_point,
        source_dir=None,
        hyperparameters=None,
        py_version="py3",
        framework_version=None,
        image_name=None,
        distributions=None,
        **kwargs
    ):
        super(CustomFramework, self).__init__(
            entry_point, source_dir, hyperparameters, image_name=image_name, **kwargs
        )
    
    def _configure_distribution(self, distributions):
        return
    
    def create_model(
        self,
        model_server_workers=None,
        role=None,
        vpc_config_override=None,
        entry_point=None,
        source_dir=None,
        dependencies=None,
        image_name=None,
        **kwargs
    ):
        return None
        
import sagemaker

est = CustomFramework(image_name=container_image_uri,
                      entry_point=train_code_file,
                      source_dir='source_dir/',
                      role=role,
                      train_instance_count=1, 
                      train_instance_type='local', # we use local mode
                      #train_instance_type='ml.m5.xlarge',
                      base_job_name='byoc-cifar10',
                      hyperparameters={'epochs': "1", 
                                       'model_dir' : './logs'
                                      },                      
                        )

# train_config = sagemaker.session.s3_input('s3://{0}/{1}/train/'.format(bucket, prefix), content_type='text/csv')
# val_config = sagemaker.session.s3_input('s3://{0}/{1}/val/'.format(bucket, prefix), content_type='text/csv')

# est.fit({'train': train_config, 'validation': val_config })

est.fit({'train':'{}/train'.format(dataset_location),
              'validation':'{}/validation'.format(dataset_location),
              'eval':'{}/eval'.format(dataset_location)})
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# image_name has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Building with native build. Learn about native build in Compose here: https://docs.docker.com/go/compose-native-build/
# Creating 8xhzvjh05j-algo-1-cty20 ...
# Creating 8xhzvjh05j-algo-1-cty20 ... done
# Attaching to 8xhzvjh05j-algo-1-cty20
# 8xhzvjh05j-algo-1-cty20 | 2021-02-25 12:43:40,678 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# 8xhzvjh05j-algo-1-cty20 | /usr/bin/python3 -m pip install -r requirements.txt
# 8xhzvjh05j-algo-1-cty20 | /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
# 8xhzvjh05j-algo-1-cty20 |   from cryptography.utils import int_from_bytes
# 8xhzvjh05j-algo-1-cty20 | /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
# 8xhzvjh05j-algo-1-cty20 |   from cryptography.utils import int_from_bytes
# 8xhzvjh05j-algo-1-cty20 | Collecting pandas<2
# 8xhzvjh05j-algo-1-cty20 |   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 2.4 MB/s eta 0:00:01
# 8xhzvjh05j-algo-1-cty20 | Collecting pytz>=2017.2
# 8xhzvjh05j-algo-1-cty20 |   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 30.8 MB/s eta 0:00:01
# 8xhzvjh05j-algo-1-cty20 | Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (2.8.1)
# 8xhzvjh05j-algo-1-cty20 | Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (1.18.2)
# 8xhzvjh05j-algo-1-cty20 | Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas<2->-r requirements.txt (line 1)) (1.14.0)
# 8xhzvjh05j-algo-1-cty20 | Installing collected packages: pytz, pandas
# 8xhzvjh05j-algo-1-cty20 | Successfully installed pandas-1.1.5 pytz-2021.1
# 8xhzvjh05j-algo-1-cty20 | WARNING: You are using pip version 20.0.2; however, version 21.0.1 is available.
# 8xhzvjh05j-algo-1-cty20 | You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# 8xhzvjh05j-algo-1-cty20 | 2021-02-25 12:43:46,184 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 8xhzvjh05j-algo-1-cty20 | 2021-02-25 12:43:46,195 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 8xhzvjh05j-algo-1-cty20 | 2021-02-25 12:43:46,204 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 8xhzvjh05j-algo-1-cty20 | 2021-02-25 12:43:46,213 sagemaker-training-toolkit INFO     Invoking user script
# 8xhzvjh05j-algo-1-cty20 |
# 8xhzvjh05j-algo-1-cty20 | Training Env:
# 8xhzvjh05j-algo-1-cty20 |
# 8xhzvjh05j-algo-1-cty20 | {
# 8xhzvjh05j-algo-1-cty20 |     "additional_framework_parameters": {},
# 8xhzvjh05j-algo-1-cty20 |     "channel_input_dirs": {
# 8xhzvjh05j-algo-1-cty20 |         "train": "/opt/ml/input/data/train",
# 8xhzvjh05j-algo-1-cty20 |         "validation": "/opt/ml/input/data/validation",
# 8xhzvjh05j-algo-1-cty20 |         "eval": "/opt/ml/input/data/eval"
# 8xhzvjh05j-algo-1-cty20 |     },
# 8xhzvjh05j-algo-1-cty20 |     "current_host": "algo-1-cty20",
# 8xhzvjh05j-algo-1-cty20 |     "framework_module": null,
# 8xhzvjh05j-algo-1-cty20 |     "hosts": [
# 8xhzvjh05j-algo-1-cty20 |         "algo-1-cty20"
# 8xhzvjh05j-algo-1-cty20 |     ],
# 8xhzvjh05j-algo-1-cty20 |     "hyperparameters": {
# 8xhzvjh05j-algo-1-cty20 |         "epochs": "1",
# 8xhzvjh05j-algo-1-cty20 |         "model_dir": "./logs"
# 8xhzvjh05j-algo-1-cty20 |     },
# 8xhzvjh05j-algo-1-cty20 |     "input_config_dir": "/opt/ml/input/config",
# 8xhzvjh05j-algo-1-cty20 |     "input_data_config": {
# 8xhzvjh05j-algo-1-cty20 |         "train": {
# 8xhzvjh05j-algo-1-cty20 |             "TrainingInputMode": "File"
# 8xhzvjh05j-algo-1-cty20 |         },
# 8xhzvjh05j-algo-1-cty20 |         "validation": {
# 8xhzvjh05j-algo-1-cty20 |             "TrainingInputMode": "File"
# 8xhzvjh05j-algo-1-cty20 |         },
# 8xhzvjh05j-algo-1-cty20 |         "eval": {
# 8xhzvjh05j-algo-1-cty20 |             "TrainingInputMode": "File"
# 8xhzvjh05j-algo-1-cty20 |         }
# 8xhzvjh05j-algo-1-cty20 |     },
# 8xhzvjh05j-algo-1-cty20 |     "input_dir": "/opt/ml/input",
# 8xhzvjh05j-algo-1-cty20 |     "is_master": true,
# 8xhzvjh05j-algo-1-cty20 |     "job_name": "byoc-cifar10-2021-02-25-12-43-37-403",
# 8xhzvjh05j-algo-1-cty20 |     "log_level": 20,
# 8xhzvjh05j-algo-1-cty20 |     "master_hostname": "algo-1-cty20",
# 8xhzvjh05j-algo-1-cty20 |     "model_dir": "/opt/ml/model",
# 8xhzvjh05j-algo-1-cty20 |     "module_dir": "s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10-2021-02-25-12-43-37-403/source/sourcedir.tar.gz",
# 8xhzvjh05j-algo-1-cty20 |     "module_name": "cifar10_keras_sm_tf2",
# 8xhzvjh05j-algo-1-cty20 |     "network_interface_name": "eth0",
# 8xhzvjh05j-algo-1-cty20 |     "num_cpus": 36,
# 8xhzvjh05j-algo-1-cty20 |     "num_gpus": 0,
# 8xhzvjh05j-algo-1-cty20 |     "output_data_dir": "/opt/ml/output/data",
# 8xhzvjh05j-algo-1-cty20 |     "output_dir": "/opt/ml/output",
# 8xhzvjh05j-algo-1-cty20 |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# 8xhzvjh05j-algo-1-cty20 |     "resource_config": {
# 8xhzvjh05j-algo-1-cty20 |         "current_host": "algo-1-cty20",
# 8xhzvjh05j-algo-1-cty20 |         "hosts": [
# 8xhzvjh05j-algo-1-cty20 |             "algo-1-cty20"
# 8xhzvjh05j-algo-1-cty20 |         ]
# 8xhzvjh05j-algo-1-cty20 |     },
# 8xhzvjh05j-algo-1-cty20 |     "user_entry_point": "cifar10_keras_sm_tf2.py"
# 8xhzvjh05j-algo-1-cty20 | }
# 8xhzvjh05j-algo-1-cty20 |
# 8xhzvjh05j-algo-1-cty20 | Environment variables:
# 8xhzvjh05j-algo-1-cty20 |
# 8xhzvjh05j-algo-1-cty20 | SM_HOSTS=["algo-1-cty20"]
# 8xhzvjh05j-algo-1-cty20 | SM_NETWORK_INTERFACE_NAME=eth0
# 8xhzvjh05j-algo-1-cty20 | SM_HPS={"epochs":"1","model_dir":"./logs"}
# 8xhzvjh05j-algo-1-cty20 | SM_USER_ENTRY_POINT=cifar10_keras_sm_tf2.py
# 8xhzvjh05j-algo-1-cty20 | SM_FRAMEWORK_PARAMS={}
# 8xhzvjh05j-algo-1-cty20 | SM_RESOURCE_CONFIG={"current_host":"algo-1-cty20","hosts":["algo-1-cty20"]}
# 8xhzvjh05j-algo-1-cty20 | SM_INPUT_DATA_CONFIG={"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}}
# 8xhzvjh05j-algo-1-cty20 | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# 8xhzvjh05j-algo-1-cty20 | SM_CHANNELS=["eval","train","validation"]
# 8xhzvjh05j-algo-1-cty20 | SM_CURRENT_HOST=algo-1-cty20
# 8xhzvjh05j-algo-1-cty20 | SM_MODULE_NAME=cifar10_keras_sm_tf2
# 8xhzvjh05j-algo-1-cty20 | SM_LOG_LEVEL=20
# 8xhzvjh05j-algo-1-cty20 | SM_FRAMEWORK_MODULE=
# 8xhzvjh05j-algo-1-cty20 | SM_INPUT_DIR=/opt/ml/input
# 8xhzvjh05j-algo-1-cty20 | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# 8xhzvjh05j-algo-1-cty20 | SM_OUTPUT_DIR=/opt/ml/output
# 8xhzvjh05j-algo-1-cty20 | SM_NUM_CPUS=36
# 8xhzvjh05j-algo-1-cty20 | SM_NUM_GPUS=0
# 8xhzvjh05j-algo-1-cty20 | SM_MODEL_DIR=/opt/ml/model
# 8xhzvjh05j-algo-1-cty20 | SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10-2021-02-25-12-43-37-403/source/sourcedir.tar.gz
# 8xhzvjh05j-algo-1-cty20 | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1-cty20","framework_module":null,"hosts":["algo-1-cty20"],"hyperparameters":{"epochs":"1","model_dir":"./logs"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"byoc-cifar10-2021-02-25-12-43-37-403","log_level":20,"master_hostname":"algo-1-cty20","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10-2021-02-25-12-43-37-403/source/sourcedir.tar.gz","module_name":"cifar10_keras_sm_tf2","network_interface_name":"eth0","num_cpus":36,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-cty20","hosts":["algo-1-cty20"]},"user_entry_point":"cifar10_keras_sm_tf2.py"}
# 8xhzvjh05j-algo-1-cty20 | SM_USER_ARGS=["--epochs","1","--model_dir","./logs"]
# 8xhzvjh05j-algo-1-cty20 | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# 8xhzvjh05j-algo-1-cty20 | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# 8xhzvjh05j-algo-1-cty20 | SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# 8xhzvjh05j-algo-1-cty20 | SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# 8xhzvjh05j-algo-1-cty20 | SM_HP_EPOCHS=1
# 8xhzvjh05j-algo-1-cty20 | SM_HP_MODEL_DIR=./logs
# 8xhzvjh05j-algo-1-cty20 | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# 8xhzvjh05j-algo-1-cty20 |
# 8xhzvjh05j-algo-1-cty20 | Invoking script with the following command:
# 8xhzvjh05j-algo-1-cty20 |
# 8xhzvjh05j-algo-1-cty20 | /usr/bin/python3 cifar10_keras_sm_tf2.py --epochs 1 --model_dir ./logs
# 8xhzvjh05j-algo-1-cty20 |
# 8xhzvjh05j-algo-1-cty20 |
# 8xhzvjh05j-algo-1-cty20 | 2021-02-25 12:43:47.655143: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 8xhzvjh05j-algo-1-cty20 | 2021-02-25 12:43:47.655169: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: UNKNOWN ERROR (-1)
# 8xhzvjh05j-algo-1-cty20 | 2021-02-25 12:43:47.655193: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (3c08c64b5037): /proc/driver/nvidia/version does not exist
# 8xhzvjh05j-algo-1-cty20 | 2021-02-25 12:43:47.655416: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 8xhzvjh05j-algo-1-cty20 | 2021-02-25 12:43:47.681143: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 3000000000 Hz
# 8xhzvjh05j-algo-1-cty20 | 2021-02-25 12:43:47.683069: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f01f4000b20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 8xhzvjh05j-algo-1-cty20 | 2021-02-25 12:43:47.683086: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 312/312 [==============================] - 19s 62ms/step - loss: 1.8539 - accuracy: 0.3124 - val_loss: 1.6446 - val_accuracy: 0.3906
# 8xhzvjh05j-algo-1-cty20 | 2021-02-25 12:44:11.013259: W tensorflow/python/util/util.cc:329] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 8xhzvjh05j-algo-1-cty20 | WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# 8xhzvjh05j-algo-1-cty20 | Instructions for updating:
# 8xhzvjh05j-algo-1-cty20 | If using Keras pass *_constraint arguments to layers.
# 8xhzvjh05j-algo-1-cty20 | WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# 8xhzvjh05j-algo-1-cty20 | Instructions for updating:
# 8xhzvjh05j-algo-1-cty20 | If using Keras pass *_constraint arguments to layers.
# 8xhzvjh05j-algo-1-cty20 | INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# 8xhzvjh05j-algo-1-cty20 | INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# 8xhzvjh05j-algo-1-cty20 | 2021-02-25 12:44:12,890 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# 8xhzvjh05j-algo-1-cty20 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %% [markdown]
# ## S3 Code에서 실행
#
# 현재의 training_job_name을 저장 합니다.
# - training_job_name을 에는 훈련에 관련 내용 및 훈련 결과인 **Model Artifact** 파일의 S3 경로를 제공 합니다.

# %%
import tarfile
import os

def create_tar_file(source_files, target=None):
    if target:
        filename = target
    else:
        _, filename = tempfile.mkstemp()

    with tarfile.open(filename, mode="w:gz") as t:
        for sf in source_files:
            # Add all files from the directory into the root of the directory structure of the tar
            t.add(sf, arcname=os.path.basename(sf))
    return filename

create_tar_file(["source_dir/cifar10_keras_sm_tf2.py", "source_dir/requirements.txt"], "sourcedir.tar.gz")
# Out:
# 'sourcedir.tar.gz'

# %%
sources = sagemaker_session.upload_data('sourcedir.tar.gz', bucket, prefix + '/code')
print(sources)
! rm sourcedir.tar.gz
# Out:
# s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz

# %% [markdown]
# When starting the training job, we need to let the sagemaker-training-toolkit library know where the sources are stored in Amazon S3 and what is the module to be invoked. These parameters are specified through the following reserved hyperparameters (these reserved hyperparameters are injected automatically when using framework estimators of the Amazon SageMaker Python SDK):
# <ul>
#     <li>sagemaker_program</li>
#     <li>sagemaker_submit_directory</li>
# </ul>
#
# Finally, we can execute the training job by calling the fit() method of the generic Estimator object defined in the Amazon SageMaker Python SDK (https://github.com/aws/sagemaker-python-sdk/blob/master/src/sagemaker/estimator.py). This corresponds to calling the CreateTrainingJob() API (https://docs.aws.amazon.com/sagemaker/latest/dg/API_CreateTrainingJob.html).

# %%
import sagemaker
import json
# JSON encode hyperparameters.
def json_encode_hyperparameters(hyperparameters):
    return {str(k): json.dumps(v) for (k, v) in hyperparameters.items()}

hyperparameters = json_encode_hyperparameters({
    "sagemaker_program": train_code_file,
    "sagemaker_submit_directory": sources,
    'epochs': "1", 
    'model_dir' : './logs'    
    })

hyperparameters
# Out:
# {'sagemaker_program': '"cifar10_keras_sm_tf2.py"',
#  'sagemaker_submit_directory': '"s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz"',
#  'epochs': '"1"',
#  'model_dir': '"./logs"'}

# %%
est = sagemaker.estimator.Estimator(container_image_uri,
                                    role,
                                    train_instance_count=1, 
                                    train_instance_type='local',
                                    base_job_name=prefix,
                                    hyperparameters=hyperparameters)

# train_config = sagemaker.session.s3_input('s3://{0}/{1}/train/'.format(bucket, prefix), content_type='text/csv')
# val_config = sagemaker.session.s3_input('s3://{0}/{1}/val/'.format(bucket, prefix), content_type='text/csv')

# est.fit({'train': train_config, 'validation': val_config })

est.fit({'train':'{}/train'.format(dataset_location),
              'validation':'{}/validation'.format(dataset_location),
              'eval':'{}/eval'.format(dataset_location)})
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Building with native build. Learn about native build in Compose here: https://docs.docker.com/go/compose-native-build/
# Creating ngdmjrvhn8-algo-1-tid01 ...
# Creating ngdmjrvhn8-algo-1-tid01 ... done
# Attaching to ngdmjrvhn8-algo-1-tid01
# ngdmjrvhn8-algo-1-tid01 | 2021-02-25 12:44:19,384 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# ngdmjrvhn8-algo-1-tid01 | /usr/bin/python3 -m pip install -r requirements.txt
# ngdmjrvhn8-algo-1-tid01 | /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
# ngdmjrvhn8-algo-1-tid01 |   from cryptography.utils import int_from_bytes
# ngdmjrvhn8-algo-1-tid01 | /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
# ngdmjrvhn8-algo-1-tid01 |   from cryptography.utils import int_from_bytes
# ngdmjrvhn8-algo-1-tid01 | Collecting pandas<2
# ngdmjrvhn8-algo-1-tid01 |   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 2.3 MB/s eta 0:00:01
# ngdmjrvhn8-algo-1-tid01 | Collecting pytz>=2017.2
# ngdmjrvhn8-algo-1-tid01 |   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 30.1 MB/s eta 0:00:01
# ngdmjrvhn8-algo-1-tid01 | Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (2.8.1)
# ngdmjrvhn8-algo-1-tid01 | Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (1.18.2)
# ngdmjrvhn8-algo-1-tid01 | Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas<2->-r requirements.txt (line 1)) (1.14.0)
# ngdmjrvhn8-algo-1-tid01 | Installing collected packages: pytz, pandas
# ngdmjrvhn8-algo-1-tid01 | Successfully installed pandas-1.1.5 pytz-2021.1
# ngdmjrvhn8-algo-1-tid01 | WARNING: You are using pip version 20.0.2; however, version 21.0.1 is available.
# ngdmjrvhn8-algo-1-tid01 | You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# ngdmjrvhn8-algo-1-tid01 | 2021-02-25 12:44:24,873 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# ngdmjrvhn8-algo-1-tid01 | 2021-02-25 12:44:24,883 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# ngdmjrvhn8-algo-1-tid01 | 2021-02-25 12:44:24,892 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# ngdmjrvhn8-algo-1-tid01 | 2021-02-25 12:44:24,902 sagemaker-training-toolkit INFO     Invoking user script
# ngdmjrvhn8-algo-1-tid01 |
# ngdmjrvhn8-algo-1-tid01 | Training Env:
# ngdmjrvhn8-algo-1-tid01 |
# ngdmjrvhn8-algo-1-tid01 | {
# ngdmjrvhn8-algo-1-tid01 |     "additional_framework_parameters": {},
# ngdmjrvhn8-algo-1-tid01 |     "channel_input_dirs": {
# ngdmjrvhn8-algo-1-tid01 |         "train": "/opt/ml/input/data/train",
# ngdmjrvhn8-algo-1-tid01 |         "validation": "/opt/ml/input/data/validation",
# ngdmjrvhn8-algo-1-tid01 |         "eval": "/opt/ml/input/data/eval"
# ngdmjrvhn8-algo-1-tid01 |     },
# ngdmjrvhn8-algo-1-tid01 |     "current_host": "algo-1-tid01",
# ngdmjrvhn8-algo-1-tid01 |     "framework_module": null,
# ngdmjrvhn8-algo-1-tid01 |     "hosts": [
# ngdmjrvhn8-algo-1-tid01 |         "algo-1-tid01"
# ngdmjrvhn8-algo-1-tid01 |     ],
# ngdmjrvhn8-algo-1-tid01 |     "hyperparameters": {
# ngdmjrvhn8-algo-1-tid01 |         "epochs": "1",
# ngdmjrvhn8-algo-1-tid01 |         "model_dir": "./logs"
# ngdmjrvhn8-algo-1-tid01 |     },
# ngdmjrvhn8-algo-1-tid01 |     "input_config_dir": "/opt/ml/input/config",
# ngdmjrvhn8-algo-1-tid01 |     "input_data_config": {
# ngdmjrvhn8-algo-1-tid01 |         "train": {
# ngdmjrvhn8-algo-1-tid01 |             "TrainingInputMode": "File"
# ngdmjrvhn8-algo-1-tid01 |         },
# ngdmjrvhn8-algo-1-tid01 |         "validation": {
# ngdmjrvhn8-algo-1-tid01 |             "TrainingInputMode": "File"
# ngdmjrvhn8-algo-1-tid01 |         },
# ngdmjrvhn8-algo-1-tid01 |         "eval": {
# ngdmjrvhn8-algo-1-tid01 |             "TrainingInputMode": "File"
# ngdmjrvhn8-algo-1-tid01 |         }
# ngdmjrvhn8-algo-1-tid01 |     },
# ngdmjrvhn8-algo-1-tid01 |     "input_dir": "/opt/ml/input",
# ngdmjrvhn8-algo-1-tid01 |     "is_master": true,
# ngdmjrvhn8-algo-1-tid01 |     "job_name": "byoc-cifar10-2021-02-25-12-44-16-288",
# ngdmjrvhn8-algo-1-tid01 |     "log_level": 20,
# ngdmjrvhn8-algo-1-tid01 |     "master_hostname": "algo-1-tid01",
# ngdmjrvhn8-algo-1-tid01 |     "model_dir": "/opt/ml/model",
# ngdmjrvhn8-algo-1-tid01 |     "module_dir": "s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz",
# ngdmjrvhn8-algo-1-tid01 |     "module_name": "cifar10_keras_sm_tf2",
# ngdmjrvhn8-algo-1-tid01 |     "network_interface_name": "eth0",
# ngdmjrvhn8-algo-1-tid01 |     "num_cpus": 36,
# ngdmjrvhn8-algo-1-tid01 |     "num_gpus": 0,
# ngdmjrvhn8-algo-1-tid01 |     "output_data_dir": "/opt/ml/output/data",
# ngdmjrvhn8-algo-1-tid01 |     "output_dir": "/opt/ml/output",
# ngdmjrvhn8-algo-1-tid01 |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# ngdmjrvhn8-algo-1-tid01 |     "resource_config": {
# ngdmjrvhn8-algo-1-tid01 |         "current_host": "algo-1-tid01",
# ngdmjrvhn8-algo-1-tid01 |         "hosts": [
# ngdmjrvhn8-algo-1-tid01 |             "algo-1-tid01"
# ngdmjrvhn8-algo-1-tid01 |         ]
# ngdmjrvhn8-algo-1-tid01 |     },
# ngdmjrvhn8-algo-1-tid01 |     "user_entry_point": "cifar10_keras_sm_tf2.py"
# ngdmjrvhn8-algo-1-tid01 | }
# ngdmjrvhn8-algo-1-tid01 |
# ngdmjrvhn8-algo-1-tid01 | Environment variables:
# ngdmjrvhn8-algo-1-tid01 |
# ngdmjrvhn8-algo-1-tid01 | SM_HOSTS=["algo-1-tid01"]
# ngdmjrvhn8-algo-1-tid01 | SM_NETWORK_INTERFACE_NAME=eth0
# ngdmjrvhn8-algo-1-tid01 | SM_HPS={"epochs":"1","model_dir":"./logs"}
# ngdmjrvhn8-algo-1-tid01 | SM_USER_ENTRY_POINT=cifar10_keras_sm_tf2.py
# ngdmjrvhn8-algo-1-tid01 | SM_FRAMEWORK_PARAMS={}
# ngdmjrvhn8-algo-1-tid01 | SM_RESOURCE_CONFIG={"current_host":"algo-1-tid01","hosts":["algo-1-tid01"]}
# ngdmjrvhn8-algo-1-tid01 | SM_INPUT_DATA_CONFIG={"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}}
# ngdmjrvhn8-algo-1-tid01 | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# ngdmjrvhn8-algo-1-tid01 | SM_CHANNELS=["eval","train","validation"]
# ngdmjrvhn8-algo-1-tid01 | SM_CURRENT_HOST=algo-1-tid01
# ngdmjrvhn8-algo-1-tid01 | SM_MODULE_NAME=cifar10_keras_sm_tf2
# ngdmjrvhn8-algo-1-tid01 | SM_LOG_LEVEL=20
# ngdmjrvhn8-algo-1-tid01 | SM_FRAMEWORK_MODULE=
# ngdmjrvhn8-algo-1-tid01 | SM_INPUT_DIR=/opt/ml/input
# ngdmjrvhn8-algo-1-tid01 | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# ngdmjrvhn8-algo-1-tid01 | SM_OUTPUT_DIR=/opt/ml/output
# ngdmjrvhn8-algo-1-tid01 | SM_NUM_CPUS=36
# ngdmjrvhn8-algo-1-tid01 | SM_NUM_GPUS=0
# ngdmjrvhn8-algo-1-tid01 | SM_MODEL_DIR=/opt/ml/model
# ngdmjrvhn8-algo-1-tid01 | SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz
# ngdmjrvhn8-algo-1-tid01 | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1-tid01","framework_module":null,"hosts":["algo-1-tid01"],"hyperparameters":{"epochs":"1","model_dir":"./logs"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"byoc-cifar10-2021-02-25-12-44-16-288","log_level":20,"master_hostname":"algo-1-tid01","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz","module_name":"cifar10_keras_sm_tf2","network_interface_name":"eth0","num_cpus":36,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-tid01","hosts":["algo-1-tid01"]},"user_entry_point":"cifar10_keras_sm_tf2.py"}
# ngdmjrvhn8-algo-1-tid01 | SM_USER_ARGS=["--epochs","1","--model_dir","./logs"]
# ngdmjrvhn8-algo-1-tid01 | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# ngdmjrvhn8-algo-1-tid01 | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# ngdmjrvhn8-algo-1-tid01 | SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# ngdmjrvhn8-algo-1-tid01 | SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# ngdmjrvhn8-algo-1-tid01 | SM_HP_EPOCHS=1
# ngdmjrvhn8-algo-1-tid01 | SM_HP_MODEL_DIR=./logs
# ngdmjrvhn8-algo-1-tid01 | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# ngdmjrvhn8-algo-1-tid01 |
# ngdmjrvhn8-algo-1-tid01 | Invoking script with the following command:
# ngdmjrvhn8-algo-1-tid01 |
# ngdmjrvhn8-algo-1-tid01 | /usr/bin/python3 cifar10_keras_sm_tf2.py --epochs 1 --model_dir ./logs
# ngdmjrvhn8-algo-1-tid01 |
# ngdmjrvhn8-algo-1-tid01 |
# ngdmjrvhn8-algo-1-tid01 | 2021-02-25 12:44:26.355184: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ngdmjrvhn8-algo-1-tid01 | 2021-02-25 12:44:26.355213: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: UNKNOWN ERROR (-1)
# ngdmjrvhn8-algo-1-tid01 | 2021-02-25 12:44:26.355234: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ceb55f38ab2e): /proc/driver/nvidia/version does not exist
# ngdmjrvhn8-algo-1-tid01 | 2021-02-25 12:44:26.355457: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# ngdmjrvhn8-algo-1-tid01 | 2021-02-25 12:44:26.381093: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 3000000000 Hz
# ngdmjrvhn8-algo-1-tid01 | 2021-02-25 12:44:26.382811: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fa964000b20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ngdmjrvhn8-algo-1-tid01 | 2021-02-25 12:44:26.382828: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 312/312 [==============================] - 19s 62ms/step - loss: 1.8543 - accuracy: 0.3174 - val_loss: 2.0942 - val_accuracy: 0.2878
# ngdmjrvhn8-algo-1-tid01 | 2021-02-25 12:44:49.653085: W tensorflow/python/util/util.cc:329] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# ngdmjrvhn8-algo-1-tid01 | WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# ngdmjrvhn8-algo-1-tid01 | Instructions for updating:
# ngdmjrvhn8-algo-1-tid01 | If using Keras pass *_constraint arguments to layers.
# ngdmjrvhn8-algo-1-tid01 | WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# ngdmjrvhn8-algo-1-tid01 | Instructions for updating:
# ngdmjrvhn8-algo-1-tid01 | If using Keras pass *_constraint arguments to layers.
# ngdmjrvhn8-algo-1-tid01 | INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# ngdmjrvhn8-algo-1-tid01 | INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# ngdmjrvhn8-algo-1-tid01 | 2021-02-25 12:44:51,509 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# ngdmjrvhn8-algo-1-tid01 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %% [markdown]
# ## 사용자 정의 컨테이너로 SageMaker Cloud 에서 학습

# %%
est = sagemaker.estimator.Estimator(container_image_uri, # 사용자 정의 컨테이너
                                    role,
                                    train_instance_count=1, 
                                    train_instance_type='ml.p2.xlarge',
                                    base_job_name=prefix,
                                    hyperparameters=hyperparameters)

est.fit({'train':'{}/train'.format(dataset_location),
              'validation':'{}/validation'.format(dataset_location),
              'eval':'{}/eval'.format(dataset_location)})
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2021-02-25 12:44:54 Starting - Starting the training job...
# 2021-02-25 12:45:19 Starting - Launching requested ML instancesProfilerReport-1614257094: InProgress
# ......
# 2021-02-25 12:46:19 Starting - Preparing the instances for training......
# 2021-02-25 12:47:20 Downloading - Downloading input data...
# 2021-02-25 12:47:40 Training - Downloading the training image...........2021-02-25 12:49:34,686 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /usr/bin/python3 -m pip install -r requirements.txt
# /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting pandas<2
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (2.8.1)
# Collecting pytz>=2017.2
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (1.18.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas<2->-r requirements.txt (line 1)) (1.14.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.1.5 pytz-2021.1
#
# 2021-02-25 12:49:42 Training - Training image download completed. Training in progress.WARNING: You are using pip version 20.0.2; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# 2021-02-25 12:49:42,769 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "validation": "/opt/ml/input/data/validation",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": null,
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "model_dir": "./logs",
#         "epochs": "1"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "byoc-cifar10-2021-02-25-12-44-54-535",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz",
#     "module_name": "cifar10_keras_sm_tf2",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "cifar10_keras_sm_tf2.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":"1","model_dir":"./logs"}
# SM_USER_ENTRY_POINT=cifar10_keras_sm_tf2.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=cifar10_keras_sm_tf2
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":null,"hosts":["algo-1"],"hyperparameters":{"epochs":"1","model_dir":"./logs"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"byoc-cifar10-2021-02-25-12-44-54-535","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz","module_name":"cifar10_keras_sm_tf2","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"cifar10_keras_sm_tf2.py"}
# SM_USER_ARGS=["--epochs","1","--model_dir","./logs"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_DIR=./logs
# SM_HP_EPOCHS=1
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 cifar10_keras_sm_tf2.py --epochs 1 --model_dir ./logs
#
#
# 2021-02-25 12:49:47.143998: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-02-25 12:49:47.392650: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:49:47.393517: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8755GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2021-02-25 12:49:47.396312: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-25 12:49:47.472858: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-02-25 12:49:47.514619: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-02-25 12:49:47.523386: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-02-25 12:49:47.606394: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-02-25 12:49:47.616812: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-02-25 12:49:47.767487: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-02-25 12:49:47.767716: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:49:47.768680: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:49:47.769467: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-02-25 12:49:47.771042: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-02-25 12:49:47.790417: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300075000 Hz
# 2021-02-25 12:49:47.790948: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f5ff8000b20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-02-25 12:49:47.790983: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-02-25 12:49:48.083922: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:49:48.084927: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55c2160 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-02-25 12:49:48.084961: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2021-02-25 12:49:48.087178: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:49:48.087950: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8755GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2021-02-25 12:49:48.088025: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-25 12:49:48.088057: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-02-25 12:49:48.088093: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-02-25 12:49:48.088123: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-02-25 12:49:48.088153: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-02-25 12:49:48.088232: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-02-25 12:49:48.088269: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-02-25 12:49:48.088374: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:49:48.089213: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:49:48.089980: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-02-25 12:49:48.090969: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-25 12:49:48.093748: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-02-25 12:49:48.093779: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2021-02-25 12:49:48.093792: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2021-02-25 12:49:48.095012: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:49:48.095853: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 12:49:48.096667: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10699 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0, compute capability: 3.7)
# 2021-02-25 12:49:52.747485: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-02-25 12:49:55.946229: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# #015  1/312 [..............................] - ETA: 0s - loss: 4.1927 - accuracy: 0.0859#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  3/312 [..............................] - ETA: 6s - loss: 3.7199 - accuracy: 0.1068#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  5/312 [..............................] - ETA: 7s - loss: 3.6765 - accuracy: 0.1109#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  7/312 [..............................] - ETA: 7s - loss: 3.5136 - accuracy: 0.1205#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  9/312 [..............................] - ETA: 7s - loss: 3.3120 - accuracy: 0.1337#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 11/312 [>.............................] - ETA: 7s - loss: 3.1870 - accuracy: 0.1392#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 13/312 [>.............................] - ETA: 7s - loss: 3.0879 - accuracy: 0.1472#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 15/312 [>.............................] - ETA: 7s - loss: 3.0267 - accuracy: 0.1479#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 17/312 [>.............................] - ETA: 7s - loss: 2.9468 - accuracy: 0.1489#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 19/312 [>.............................] - ETA: 7s - loss: 2.8729 - accuracy: 0.1554#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010 ...
# #010#010#010#010#010#010#010#010#010#015194/312 [=================>............] - ETA: 3s - loss: 1.9791 - accuracy: 0.2790#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015196/312 [=================>............] - ETA: 3s - loss: 1.9760 - accuracy: 0.2802#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015198/312 [==================>...........] - ETA: 3s - loss: 1.9736 - accuracy: 0.2811#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015200/312 [==================>...........] - ETA: 3s - loss: 1.9712 - accuracy: 0.2823#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015202/312 [==================>...........] - ETA: 3s - loss: 1.9691 - accuracy: 0.2831#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015204/312 [==================>...........] - ETA: 3s - loss: 1.9668 - accuracy: 0.2835#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015206/312 [==================>...........] - ETA: 3s - loss: 1.9642 - accuracy: 0.2843#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015208/312 [===================>..........] - ETA: 3s - loss: 1.9617 - accuracy: 0.2848#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015210/312 [===================>..........] - ETA: 3s - loss: 1.9586 - accuracy: 0.2859#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015212/312 [===================>..........] - ETA: 3s - loss: 1.9564 - accuracy: 0.2868#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010 ...
# 2021-02-25 12:50:12.657114: W tensorflow/python/util/util.cc:329] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
#
# 2021-02-25 12:50:22 Uploading - Uploading generated training modelINFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# 2021-02-25 12:50:16,112 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2021-02-25 12:50:43 Completed - Training job completed
# ProfilerReport-1614257094: NoIssuesFound
# Training seconds: 191
# Billable seconds: 191

# %%
train_job_name = estimator._current_job_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-6813c7ccbb02> in <module>
# ----> 1 train_job_name = estimator._current_job_name
#
# NameError: name 'estimator' is not defined

# %%
# %store train_job_name
