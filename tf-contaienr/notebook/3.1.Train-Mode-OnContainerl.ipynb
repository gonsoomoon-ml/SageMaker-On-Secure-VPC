# %% [markdown]
# # [모듈 3.1] 사용자 정의 컨테이너로 학습
#
# ---

# %% [markdown]
# SageMaker의 세션을 얻고, role 정보를 가져옵니다.
# - 위의 두 정보를 통해서 SageMaker Hosting Cluster에 연결합니다.

# %%
import os
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()
sagemaker_session = sagemaker.session.Session()
bucket = sagemaker_session.default_bucket()
prefix = 'byoc-cifar10'

# %% [markdown]
# ## 로컬의 데이터 S3 업로딩
# 로컬의 데이터를 S3에 업로딩하여 훈련시에 Input으로 사용 합니다.

# %%
dataset_location = sagemaker_session.upload_data(path='data', key_prefix='data/DEMO-cifar10')
display(dataset_location)
# Out:
# 's3://sagemaker-ap-northeast-2-057716757052/data/DEMO-cifar10'

# %%
# %store -r container_image_uri
print (container_image_uri)
# Out:
# 057716757052.dkr.ecr.ap-northeast-2.amazonaws.com/sagemaker-training-containers/tf-script-mode-container-2:latest

# %%
train_code_file = 'cifar10_keras_sm_tf2.py'

# %% [markdown]
# <h3>Training with a custom SDK framework estimator</h3>

# %% [markdown]
# As you have seen, in the previous steps we had to upload our code to Amazon S3 and then inject reserved hyperparameters to execute training. In order to facilitate this task, you can also try defining a custom framework estimator using the Amazon SageMaker Python SDK and run training with that class, which will take care of managing these tasks.

# %% [markdown]
# ## output bucket 지정
# 모델의 아티펙트 등이 결과물이 저장될 버킷 지정. output 버킷을 지정하지 않으면, 세이지 메이커의 디폴트 버킷에 저장이 됨

# %%
output_bucket = 'gonsoo-share' # 본인의 버켓으로 바꾸어 주세요
output_prefix = 'cifar10-output'
s3_output_path = f's3://{output_bucket}/{output_prefix}'
print(s3_output_path)
# Out:
# s3://gonsoo-share/cifar10-output

# %%
from sagemaker.estimator import Framework

class CustomFramework(Framework):
    def __init__(
        self,
        entry_point,
        source_dir=None,
        hyperparameters=None,
        py_version="py3",
        framework_version=None,
        image_name=None,
        distributions=None,
        **kwargs
    ):
        super(CustomFramework, self).__init__(
            entry_point, source_dir, hyperparameters, image_name=image_name, **kwargs
        )
    
    def _configure_distribution(self, distributions):
        return
    
    def create_model(
        self,
        model_server_workers=None,
        role=None,
        vpc_config_override=None,
        entry_point=None,
        source_dir=None,
        dependencies=None,
        image_name=None,
        **kwargs
    ):
        return None
        
import sagemaker

# 'model_dir' : './logs' 코드는 더미 코드 임. 기존의 코드와 호환성을 위해서 사용 함
# 실제 모델 아티펙트의 결과는 s3_output_path 에 저장 됨
est = CustomFramework(image_name=container_image_uri,
                      entry_point=train_code_file,
                      source_dir='source_dir/',
                      output_path = s3_output_path,                                             
                      role=role,
                      train_instance_count=1, 
                      train_instance_type='local', # we use local mode
                      #train_instance_type='ml.m5.xlarge',
                      base_job_name='byoc-cifar10',
                      hyperparameters={'epochs': "1", 
                                       'model_dir' : './logs'
                                      },    

                      
                     )

est.fit({'train':'{}/train'.format(dataset_location),
              'validation':'{}/validation'.format(dataset_location),
              'eval':'{}/eval'.format(dataset_location)})
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# image_name has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Building with native build. Learn about native build in Compose here: https://docs.docker.com/go/compose-native-build/
# Creating avmm6df9lw-algo-1-ijk1e ...
# Creating avmm6df9lw-algo-1-ijk1e ... done
# Attaching to avmm6df9lw-algo-1-ijk1e
# avmm6df9lw-algo-1-ijk1e | 2021-02-27 03:20:39,416 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# avmm6df9lw-algo-1-ijk1e | /usr/bin/python3 -m pip install -r requirements.txt
# avmm6df9lw-algo-1-ijk1e | /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
# avmm6df9lw-algo-1-ijk1e |   from cryptography.utils import int_from_bytes
# avmm6df9lw-algo-1-ijk1e | /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
# avmm6df9lw-algo-1-ijk1e |   from cryptography.utils import int_from_bytes
# avmm6df9lw-algo-1-ijk1e | Collecting pandas<2
# avmm6df9lw-algo-1-ijk1e |   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 2.4 MB/s eta 0:00:01
# avmm6df9lw-algo-1-ijk1e | Collecting pytz>=2017.2
# avmm6df9lw-algo-1-ijk1e |   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 38.9 MB/s eta 0:00:01
# avmm6df9lw-algo-1-ijk1e | Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (2.8.1)
# avmm6df9lw-algo-1-ijk1e | Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (1.18.2)
# avmm6df9lw-algo-1-ijk1e | Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas<2->-r requirements.txt (line 1)) (1.14.0)
# avmm6df9lw-algo-1-ijk1e | Installing collected packages: pytz, pandas
# avmm6df9lw-algo-1-ijk1e | Successfully installed pandas-1.1.5 pytz-2021.1
# avmm6df9lw-algo-1-ijk1e | WARNING: You are using pip version 20.0.2; however, version 21.0.1 is available.
# avmm6df9lw-algo-1-ijk1e | You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# avmm6df9lw-algo-1-ijk1e | 2021-02-27 03:20:44,863 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# avmm6df9lw-algo-1-ijk1e | 2021-02-27 03:20:44,873 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# avmm6df9lw-algo-1-ijk1e | 2021-02-27 03:20:44,883 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# avmm6df9lw-algo-1-ijk1e | 2021-02-27 03:20:44,892 sagemaker-training-toolkit INFO     Invoking user script
# avmm6df9lw-algo-1-ijk1e |
# avmm6df9lw-algo-1-ijk1e | Training Env:
# avmm6df9lw-algo-1-ijk1e |
# avmm6df9lw-algo-1-ijk1e | {
# avmm6df9lw-algo-1-ijk1e |     "additional_framework_parameters": {},
# avmm6df9lw-algo-1-ijk1e |     "channel_input_dirs": {
# avmm6df9lw-algo-1-ijk1e |         "train": "/opt/ml/input/data/train",
# avmm6df9lw-algo-1-ijk1e |         "validation": "/opt/ml/input/data/validation",
# avmm6df9lw-algo-1-ijk1e |         "eval": "/opt/ml/input/data/eval"
# avmm6df9lw-algo-1-ijk1e |     },
# avmm6df9lw-algo-1-ijk1e |     "current_host": "algo-1-ijk1e",
# avmm6df9lw-algo-1-ijk1e |     "framework_module": null,
# avmm6df9lw-algo-1-ijk1e |     "hosts": [
# avmm6df9lw-algo-1-ijk1e |         "algo-1-ijk1e"
# avmm6df9lw-algo-1-ijk1e |     ],
# avmm6df9lw-algo-1-ijk1e |     "hyperparameters": {
# avmm6df9lw-algo-1-ijk1e |         "epochs": "1",
# avmm6df9lw-algo-1-ijk1e |         "model_dir": "./logs"
# avmm6df9lw-algo-1-ijk1e |     },
# avmm6df9lw-algo-1-ijk1e |     "input_config_dir": "/opt/ml/input/config",
# avmm6df9lw-algo-1-ijk1e |     "input_data_config": {
# avmm6df9lw-algo-1-ijk1e |         "train": {
# avmm6df9lw-algo-1-ijk1e |             "TrainingInputMode": "File"
# avmm6df9lw-algo-1-ijk1e |         },
# avmm6df9lw-algo-1-ijk1e |         "validation": {
# avmm6df9lw-algo-1-ijk1e |             "TrainingInputMode": "File"
# avmm6df9lw-algo-1-ijk1e |         },
# avmm6df9lw-algo-1-ijk1e |         "eval": {
# avmm6df9lw-algo-1-ijk1e |             "TrainingInputMode": "File"
# avmm6df9lw-algo-1-ijk1e |         }
# avmm6df9lw-algo-1-ijk1e |     },
# avmm6df9lw-algo-1-ijk1e |     "input_dir": "/opt/ml/input",
# avmm6df9lw-algo-1-ijk1e |     "is_master": true,
# avmm6df9lw-algo-1-ijk1e |     "job_name": "byoc-cifar10-2021-02-27-03-20-36-121",
# avmm6df9lw-algo-1-ijk1e |     "log_level": 20,
# avmm6df9lw-algo-1-ijk1e |     "master_hostname": "algo-1-ijk1e",
# avmm6df9lw-algo-1-ijk1e |     "model_dir": "/opt/ml/model",
# avmm6df9lw-algo-1-ijk1e |     "module_dir": "s3://gonsoo-share/byoc-cifar10-2021-02-27-03-20-36-121/source/sourcedir.tar.gz",
# avmm6df9lw-algo-1-ijk1e |     "module_name": "cifar10_keras_sm_tf2",
# avmm6df9lw-algo-1-ijk1e |     "network_interface_name": "eth0",
# avmm6df9lw-algo-1-ijk1e |     "num_cpus": 36,
# avmm6df9lw-algo-1-ijk1e |     "num_gpus": 0,
# avmm6df9lw-algo-1-ijk1e |     "output_data_dir": "/opt/ml/output/data",
# avmm6df9lw-algo-1-ijk1e |     "output_dir": "/opt/ml/output",
# avmm6df9lw-algo-1-ijk1e |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# avmm6df9lw-algo-1-ijk1e |     "resource_config": {
# avmm6df9lw-algo-1-ijk1e |         "current_host": "algo-1-ijk1e",
# avmm6df9lw-algo-1-ijk1e |         "hosts": [
# avmm6df9lw-algo-1-ijk1e |             "algo-1-ijk1e"
# avmm6df9lw-algo-1-ijk1e |         ]
# avmm6df9lw-algo-1-ijk1e |     },
# avmm6df9lw-algo-1-ijk1e |     "user_entry_point": "cifar10_keras_sm_tf2.py"
# avmm6df9lw-algo-1-ijk1e | }
# avmm6df9lw-algo-1-ijk1e |
# avmm6df9lw-algo-1-ijk1e | Environment variables:
# avmm6df9lw-algo-1-ijk1e |
# avmm6df9lw-algo-1-ijk1e | SM_HOSTS=["algo-1-ijk1e"]
# avmm6df9lw-algo-1-ijk1e | SM_NETWORK_INTERFACE_NAME=eth0
# avmm6df9lw-algo-1-ijk1e | SM_HPS={"epochs":"1","model_dir":"./logs"}
# avmm6df9lw-algo-1-ijk1e | SM_USER_ENTRY_POINT=cifar10_keras_sm_tf2.py
# avmm6df9lw-algo-1-ijk1e | SM_FRAMEWORK_PARAMS={}
# avmm6df9lw-algo-1-ijk1e | SM_RESOURCE_CONFIG={"current_host":"algo-1-ijk1e","hosts":["algo-1-ijk1e"]}
# avmm6df9lw-algo-1-ijk1e | SM_INPUT_DATA_CONFIG={"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}}
# avmm6df9lw-algo-1-ijk1e | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# avmm6df9lw-algo-1-ijk1e | SM_CHANNELS=["eval","train","validation"]
# avmm6df9lw-algo-1-ijk1e | SM_CURRENT_HOST=algo-1-ijk1e
# avmm6df9lw-algo-1-ijk1e | SM_MODULE_NAME=cifar10_keras_sm_tf2
# avmm6df9lw-algo-1-ijk1e | SM_LOG_LEVEL=20
# avmm6df9lw-algo-1-ijk1e | SM_FRAMEWORK_MODULE=
# avmm6df9lw-algo-1-ijk1e | SM_INPUT_DIR=/opt/ml/input
# avmm6df9lw-algo-1-ijk1e | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# avmm6df9lw-algo-1-ijk1e | SM_OUTPUT_DIR=/opt/ml/output
# avmm6df9lw-algo-1-ijk1e | SM_NUM_CPUS=36
# avmm6df9lw-algo-1-ijk1e | SM_NUM_GPUS=0
# avmm6df9lw-algo-1-ijk1e | SM_MODEL_DIR=/opt/ml/model
# avmm6df9lw-algo-1-ijk1e | SM_MODULE_DIR=s3://gonsoo-share/byoc-cifar10-2021-02-27-03-20-36-121/source/sourcedir.tar.gz
# avmm6df9lw-algo-1-ijk1e | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1-ijk1e","framework_module":null,"hosts":["algo-1-ijk1e"],"hyperparameters":{"epochs":"1","model_dir":"./logs"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"byoc-cifar10-2021-02-27-03-20-36-121","log_level":20,"master_hostname":"algo-1-ijk1e","model_dir":"/opt/ml/model","module_dir":"s3://gonsoo-share/byoc-cifar10-2021-02-27-03-20-36-121/source/sourcedir.tar.gz","module_name":"cifar10_keras_sm_tf2","network_interface_name":"eth0","num_cpus":36,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-ijk1e","hosts":["algo-1-ijk1e"]},"user_entry_point":"cifar10_keras_sm_tf2.py"}
# avmm6df9lw-algo-1-ijk1e | SM_USER_ARGS=["--epochs","1","--model_dir","./logs"]
# avmm6df9lw-algo-1-ijk1e | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# avmm6df9lw-algo-1-ijk1e | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# avmm6df9lw-algo-1-ijk1e | SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# avmm6df9lw-algo-1-ijk1e | SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# avmm6df9lw-algo-1-ijk1e | SM_HP_EPOCHS=1
# avmm6df9lw-algo-1-ijk1e | SM_HP_MODEL_DIR=./logs
# avmm6df9lw-algo-1-ijk1e | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# avmm6df9lw-algo-1-ijk1e |
# avmm6df9lw-algo-1-ijk1e | Invoking script with the following command:
# avmm6df9lw-algo-1-ijk1e |
# avmm6df9lw-algo-1-ijk1e | /usr/bin/python3 cifar10_keras_sm_tf2.py --epochs 1 --model_dir ./logs
# avmm6df9lw-algo-1-ijk1e |
# avmm6df9lw-algo-1-ijk1e |
# avmm6df9lw-algo-1-ijk1e | 2021-02-27 03:20:46.340553: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# avmm6df9lw-algo-1-ijk1e | 2021-02-27 03:20:46.340581: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: UNKNOWN ERROR (-1)
# avmm6df9lw-algo-1-ijk1e | 2021-02-27 03:20:46.340599: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (4de6e1ececcc): /proc/driver/nvidia/version does not exist
# avmm6df9lw-algo-1-ijk1e | 2021-02-27 03:20:46.340828: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# avmm6df9lw-algo-1-ijk1e | 2021-02-27 03:20:46.369094: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 3000000000 Hz
# avmm6df9lw-algo-1-ijk1e | 2021-02-27 03:20:46.370955: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f36a4000b20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# avmm6df9lw-algo-1-ijk1e | 2021-02-27 03:20:46.370973: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# avmm6df9lw-algo-1-ijk1e | args.model_dir:  ./logs
# avmm6df9lw-algo-1-ijk1e | args.model_output_dir:  /opt/ml/model
# 312/312 [==============================] - 19s 62ms/step - loss: 1.8258 - accuracy: 0.3267 - val_loss: 1.6016 - val_accuracy: 0.4105
# avmm6df9lw-algo-1-ijk1e | 2021-02-27 03:21:09.681583: W tensorflow/python/util/util.cc:329] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# avmm6df9lw-algo-1-ijk1e | WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# avmm6df9lw-algo-1-ijk1e | Instructions for updating:
# avmm6df9lw-algo-1-ijk1e | If using Keras pass *_constraint arguments to layers.
# avmm6df9lw-algo-1-ijk1e | WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# avmm6df9lw-algo-1-ijk1e | Instructions for updating:
# avmm6df9lw-algo-1-ijk1e | If using Keras pass *_constraint arguments to layers.
# avmm6df9lw-algo-1-ijk1e | INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# avmm6df9lw-algo-1-ijk1e | INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# avmm6df9lw-algo-1-ijk1e | 2021-02-27 03:21:11,550 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# avmm6df9lw-algo-1-ijk1e exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %% [markdown]
# ## S3 Code에서 실행
#
# 현재의 training_job_name을 저장 합니다.
# - training_job_name을 에는 훈련에 관련 내용 및 훈련 결과인 **Model Artifact** 파일의 S3 경로를 제공 합니다.

# %%
import tarfile
import os

def create_tar_file(source_files, target=None):
    if target:
        filename = target
    else:
        _, filename = tempfile.mkstemp()

    with tarfile.open(filename, mode="w:gz") as t:
        for sf in source_files:
            # Add all files from the directory into the root of the directory structure of the tar
            t.add(sf, arcname=os.path.basename(sf))
    return filename

create_tar_file(["source_dir/cifar10_keras_sm_tf2.py", "source_dir/requirements.txt"], "sourcedir.tar.gz")
# Out:
# 'sourcedir.tar.gz'

# %%
sources = sagemaker_session.upload_data('sourcedir.tar.gz', bucket, prefix + '/code')
print(sources)
! rm sourcedir.tar.gz
# Out:
# s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz

# %% [markdown]
# When starting the training job, we need to let the sagemaker-training-toolkit library know where the sources are stored in Amazon S3 and what is the module to be invoked. These parameters are specified through the following reserved hyperparameters (these reserved hyperparameters are injected automatically when using framework estimators of the Amazon SageMaker Python SDK):
# <ul>
#     <li>sagemaker_program</li>
#     <li>sagemaker_submit_directory</li>
# </ul>
#
# Finally, we can execute the training job by calling the fit() method of the generic Estimator object defined in the Amazon SageMaker Python SDK (https://github.com/aws/sagemaker-python-sdk/blob/master/src/sagemaker/estimator.py). This corresponds to calling the CreateTrainingJob() API (https://docs.aws.amazon.com/sagemaker/latest/dg/API_CreateTrainingJob.html).

# %%
import sagemaker
import json
# JSON encode hyperparameters.
def json_encode_hyperparameters(hyperparameters):
    return {str(k): json.dumps(v) for (k, v) in hyperparameters.items()}

# 'model_dir' : './logs' 코드는 더미 코드 임. 기존의 코드와 호환성을 위해서 사용 함
# 실제 모델 아티펙트의 결과는 s3_output_path 에 저장 됨
hyperparameters = json_encode_hyperparameters({
    "sagemaker_program": train_code_file,
    "sagemaker_submit_directory": sources,
    'epochs': "1", 
    'model_dir' : './logs'    
    })

hyperparameters
# Out:
# {'sagemaker_program': '"cifar10_keras_sm_tf2.py"',
#  'sagemaker_submit_directory': '"s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz"',
#  'epochs': '"1"',
#  'model_dir': '"./logs"'}

# %%
est = sagemaker.estimator.Estimator(container_image_uri,
                                    role,
                                    train_instance_count=1, 
                                    train_instance_type='local',
                                    base_job_name=prefix,
                                    hyperparameters=hyperparameters,
                                    output_path = s3_output_path,                                                                                 
                                   )

est.fit({'train':'{}/train'.format(dataset_location),
              'validation':'{}/validation'.format(dataset_location),
              'eval':'{}/eval'.format(dataset_location)})
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Building with native build. Learn about native build in Compose here: https://docs.docker.com/go/compose-native-build/
# Creating gpunmvy05m-algo-1-thr3v ...
# Creating gpunmvy05m-algo-1-thr3v ... done
# Attaching to gpunmvy05m-algo-1-thr3v
# gpunmvy05m-algo-1-thr3v | 2021-02-27 03:22:03,321 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# gpunmvy05m-algo-1-thr3v | /usr/bin/python3 -m pip install -r requirements.txt
# gpunmvy05m-algo-1-thr3v | /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
# gpunmvy05m-algo-1-thr3v |   from cryptography.utils import int_from_bytes
# gpunmvy05m-algo-1-thr3v | /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
# gpunmvy05m-algo-1-thr3v |   from cryptography.utils import int_from_bytes
# gpunmvy05m-algo-1-thr3v | Collecting pandas<2
# gpunmvy05m-algo-1-thr3v |   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 2.4 MB/s eta 0:00:01
# gpunmvy05m-algo-1-thr3v | Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (2.8.1)
# gpunmvy05m-algo-1-thr3v | Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (1.18.2)
# gpunmvy05m-algo-1-thr3v | Collecting pytz>=2017.2
# gpunmvy05m-algo-1-thr3v |   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 28.9 MB/s eta 0:00:01
# gpunmvy05m-algo-1-thr3v | Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas<2->-r requirements.txt (line 1)) (1.14.0)
# gpunmvy05m-algo-1-thr3v | Installing collected packages: pytz, pandas
# gpunmvy05m-algo-1-thr3v | Successfully installed pandas-1.1.5 pytz-2021.1
# gpunmvy05m-algo-1-thr3v | WARNING: You are using pip version 20.0.2; however, version 21.0.1 is available.
# gpunmvy05m-algo-1-thr3v | You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# gpunmvy05m-algo-1-thr3v | 2021-02-27 03:22:08,792 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# gpunmvy05m-algo-1-thr3v | 2021-02-27 03:22:08,802 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# gpunmvy05m-algo-1-thr3v | 2021-02-27 03:22:08,811 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# gpunmvy05m-algo-1-thr3v | 2021-02-27 03:22:08,821 sagemaker-training-toolkit INFO     Invoking user script
# gpunmvy05m-algo-1-thr3v |
# gpunmvy05m-algo-1-thr3v | Training Env:
# gpunmvy05m-algo-1-thr3v |
# gpunmvy05m-algo-1-thr3v | {
# gpunmvy05m-algo-1-thr3v |     "additional_framework_parameters": {},
# gpunmvy05m-algo-1-thr3v |     "channel_input_dirs": {
# gpunmvy05m-algo-1-thr3v |         "train": "/opt/ml/input/data/train",
# gpunmvy05m-algo-1-thr3v |         "validation": "/opt/ml/input/data/validation",
# gpunmvy05m-algo-1-thr3v |         "eval": "/opt/ml/input/data/eval"
# gpunmvy05m-algo-1-thr3v |     },
# gpunmvy05m-algo-1-thr3v |     "current_host": "algo-1-thr3v",
# gpunmvy05m-algo-1-thr3v |     "framework_module": null,
# gpunmvy05m-algo-1-thr3v |     "hosts": [
# gpunmvy05m-algo-1-thr3v |         "algo-1-thr3v"
# gpunmvy05m-algo-1-thr3v |     ],
# gpunmvy05m-algo-1-thr3v |     "hyperparameters": {
# gpunmvy05m-algo-1-thr3v |         "epochs": "1",
# gpunmvy05m-algo-1-thr3v |         "model_dir": "./logs"
# gpunmvy05m-algo-1-thr3v |     },
# gpunmvy05m-algo-1-thr3v |     "input_config_dir": "/opt/ml/input/config",
# gpunmvy05m-algo-1-thr3v |     "input_data_config": {
# gpunmvy05m-algo-1-thr3v |         "train": {
# gpunmvy05m-algo-1-thr3v |             "TrainingInputMode": "File"
# gpunmvy05m-algo-1-thr3v |         },
# gpunmvy05m-algo-1-thr3v |         "validation": {
# gpunmvy05m-algo-1-thr3v |             "TrainingInputMode": "File"
# gpunmvy05m-algo-1-thr3v |         },
# gpunmvy05m-algo-1-thr3v |         "eval": {
# gpunmvy05m-algo-1-thr3v |             "TrainingInputMode": "File"
# gpunmvy05m-algo-1-thr3v |         }
# gpunmvy05m-algo-1-thr3v |     },
# gpunmvy05m-algo-1-thr3v |     "input_dir": "/opt/ml/input",
# gpunmvy05m-algo-1-thr3v |     "is_master": true,
# gpunmvy05m-algo-1-thr3v |     "job_name": "byoc-cifar10-2021-02-27-03-22-00-239",
# gpunmvy05m-algo-1-thr3v |     "log_level": 20,
# gpunmvy05m-algo-1-thr3v |     "master_hostname": "algo-1-thr3v",
# gpunmvy05m-algo-1-thr3v |     "model_dir": "/opt/ml/model",
# gpunmvy05m-algo-1-thr3v |     "module_dir": "s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz",
# gpunmvy05m-algo-1-thr3v |     "module_name": "cifar10_keras_sm_tf2",
# gpunmvy05m-algo-1-thr3v |     "network_interface_name": "eth0",
# gpunmvy05m-algo-1-thr3v |     "num_cpus": 36,
# gpunmvy05m-algo-1-thr3v |     "num_gpus": 0,
# gpunmvy05m-algo-1-thr3v |     "output_data_dir": "/opt/ml/output/data",
# gpunmvy05m-algo-1-thr3v |     "output_dir": "/opt/ml/output",
# gpunmvy05m-algo-1-thr3v |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# gpunmvy05m-algo-1-thr3v |     "resource_config": {
# gpunmvy05m-algo-1-thr3v |         "current_host": "algo-1-thr3v",
# gpunmvy05m-algo-1-thr3v |         "hosts": [
# gpunmvy05m-algo-1-thr3v |             "algo-1-thr3v"
# gpunmvy05m-algo-1-thr3v |         ]
# gpunmvy05m-algo-1-thr3v |     },
# gpunmvy05m-algo-1-thr3v |     "user_entry_point": "cifar10_keras_sm_tf2.py"
# gpunmvy05m-algo-1-thr3v | }
# gpunmvy05m-algo-1-thr3v |
# gpunmvy05m-algo-1-thr3v | Environment variables:
# gpunmvy05m-algo-1-thr3v |
# gpunmvy05m-algo-1-thr3v | SM_HOSTS=["algo-1-thr3v"]
# gpunmvy05m-algo-1-thr3v | SM_NETWORK_INTERFACE_NAME=eth0
# gpunmvy05m-algo-1-thr3v | SM_HPS={"epochs":"1","model_dir":"./logs"}
# gpunmvy05m-algo-1-thr3v | SM_USER_ENTRY_POINT=cifar10_keras_sm_tf2.py
# gpunmvy05m-algo-1-thr3v | SM_FRAMEWORK_PARAMS={}
# gpunmvy05m-algo-1-thr3v | SM_RESOURCE_CONFIG={"current_host":"algo-1-thr3v","hosts":["algo-1-thr3v"]}
# gpunmvy05m-algo-1-thr3v | SM_INPUT_DATA_CONFIG={"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}}
# gpunmvy05m-algo-1-thr3v | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# gpunmvy05m-algo-1-thr3v | SM_CHANNELS=["eval","train","validation"]
# gpunmvy05m-algo-1-thr3v | SM_CURRENT_HOST=algo-1-thr3v
# gpunmvy05m-algo-1-thr3v | SM_MODULE_NAME=cifar10_keras_sm_tf2
# gpunmvy05m-algo-1-thr3v | SM_LOG_LEVEL=20
# gpunmvy05m-algo-1-thr3v | SM_FRAMEWORK_MODULE=
# gpunmvy05m-algo-1-thr3v | SM_INPUT_DIR=/opt/ml/input
# gpunmvy05m-algo-1-thr3v | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# gpunmvy05m-algo-1-thr3v | SM_OUTPUT_DIR=/opt/ml/output
# gpunmvy05m-algo-1-thr3v | SM_NUM_CPUS=36
# gpunmvy05m-algo-1-thr3v | SM_NUM_GPUS=0
# gpunmvy05m-algo-1-thr3v | SM_MODEL_DIR=/opt/ml/model
# gpunmvy05m-algo-1-thr3v | SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz
# gpunmvy05m-algo-1-thr3v | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1-thr3v","framework_module":null,"hosts":["algo-1-thr3v"],"hyperparameters":{"epochs":"1","model_dir":"./logs"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"},"validation":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"byoc-cifar10-2021-02-27-03-22-00-239","log_level":20,"master_hostname":"algo-1-thr3v","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz","module_name":"cifar10_keras_sm_tf2","network_interface_name":"eth0","num_cpus":36,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-thr3v","hosts":["algo-1-thr3v"]},"user_entry_point":"cifar10_keras_sm_tf2.py"}
# gpunmvy05m-algo-1-thr3v | SM_USER_ARGS=["--epochs","1","--model_dir","./logs"]
# gpunmvy05m-algo-1-thr3v | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# gpunmvy05m-algo-1-thr3v | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# gpunmvy05m-algo-1-thr3v | SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# gpunmvy05m-algo-1-thr3v | SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# gpunmvy05m-algo-1-thr3v | SM_HP_EPOCHS=1
# gpunmvy05m-algo-1-thr3v | SM_HP_MODEL_DIR=./logs
# gpunmvy05m-algo-1-thr3v | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# gpunmvy05m-algo-1-thr3v |
# gpunmvy05m-algo-1-thr3v | Invoking script with the following command:
# gpunmvy05m-algo-1-thr3v |
# gpunmvy05m-algo-1-thr3v | /usr/bin/python3 cifar10_keras_sm_tf2.py --epochs 1 --model_dir ./logs
# gpunmvy05m-algo-1-thr3v |
# gpunmvy05m-algo-1-thr3v |
# gpunmvy05m-algo-1-thr3v | 2021-02-27 03:22:10.230111: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# gpunmvy05m-algo-1-thr3v | 2021-02-27 03:22:10.230137: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: UNKNOWN ERROR (-1)
# gpunmvy05m-algo-1-thr3v | 2021-02-27 03:22:10.230161: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (fae7c92a7ab8): /proc/driver/nvidia/version does not exist
# gpunmvy05m-algo-1-thr3v | 2021-02-27 03:22:10.230399: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# gpunmvy05m-algo-1-thr3v | 2021-02-27 03:22:10.257076: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 3000000000 Hz
# gpunmvy05m-algo-1-thr3v | 2021-02-27 03:22:10.258995: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f5fac000b20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# gpunmvy05m-algo-1-thr3v | 2021-02-27 03:22:10.259014: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 312/312 [==============================] - 19s 62ms/step - loss: 1.8426 - accuracy: 0.3286 - val_loss: 1.5901 - val_accuracy: 0.4126
# gpunmvy05m-algo-1-thr3v | 2021-02-27 03:22:33.575590: W tensorflow/python/util/util.cc:329] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# gpunmvy05m-algo-1-thr3v | WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# gpunmvy05m-algo-1-thr3v | Instructions for updating:
# gpunmvy05m-algo-1-thr3v | If using Keras pass *_constraint arguments to layers.
# gpunmvy05m-algo-1-thr3v | WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# gpunmvy05m-algo-1-thr3v | Instructions for updating:
# gpunmvy05m-algo-1-thr3v | If using Keras pass *_constraint arguments to layers.
# gpunmvy05m-algo-1-thr3v | INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# gpunmvy05m-algo-1-thr3v | INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# gpunmvy05m-algo-1-thr3v | 2021-02-27 03:22:35,462 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# gpunmvy05m-algo-1-thr3v exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %% [markdown]
# ## 사용자 정의 컨테이너로 SageMaker Cloud 에서 학습

# %%
# 'model_dir' : './logs' 코드는 더미 코드 임. 기존의 코드와 호환성을 위해서 사용 함
# 실제 모델 아티펙트의 결과는 s3_output_path 에 저장 됨
hyperparameters = json_encode_hyperparameters({
    "sagemaker_program": train_code_file,
    "sagemaker_submit_directory": sources,
    'epochs': "5", 
    'model_dir' : './logs'    
    })


est = sagemaker.estimator.Estimator(container_image_uri, # 사용자 정의 컨테이너
                                    role,
                                    train_instance_count=1, 
                                    train_instance_type='ml.p2.xlarge',
                                    base_job_name=prefix,
                                    hyperparameters=hyperparameters,
                                    output_path = s3_output_path,                                                                                 
                                   )

est.fit({'train':'{}/train'.format(dataset_location),
              'validation':'{}/validation'.format(dataset_location),
              'eval':'{}/eval'.format(dataset_location)})
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2021-02-27 03:23:30 Starting - Starting the training job...
# 2021-02-27 03:23:54 Starting - Launching requested ML instancesProfilerReport-1614396210: InProgress
# ......
# 2021-02-27 03:24:55 Starting - Preparing the instances for training......
# 2021-02-27 03:25:56 Downloading - Downloading input data...
# 2021-02-27 03:26:16 Training - Downloading the training image...........2021-02-27 03:28:11,411 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /usr/bin/python3 -m pip install -r requirements.txt
# /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting pandas<2
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (1.18.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas<2->-r requirements.txt (line 1)) (2.8.1)
# Collecting pytz>=2017.2
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas<2->-r requirements.txt (line 1)) (1.14.0)
# Installing collected packages: pytz, pandas
#
# 2021-02-27 03:28:18 Training - Training image download completed. Training in progress.Successfully installed pandas-1.1.5 pytz-2021.1
# WARNING: You are using pip version 20.0.2; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# 2021-02-27 03:28:19,145 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "validation": "/opt/ml/input/data/validation",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": null,
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "model_dir": "./logs",
#         "epochs": "5"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "byoc-cifar10-2021-02-27-03-23-30-059",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz",
#     "module_name": "cifar10_keras_sm_tf2",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "cifar10_keras_sm_tf2.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":"5","model_dir":"./logs"}
# SM_USER_ENTRY_POINT=cifar10_keras_sm_tf2.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=cifar10_keras_sm_tf2
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":null,"hosts":["algo-1"],"hyperparameters":{"epochs":"5","model_dir":"./logs"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"byoc-cifar10-2021-02-27-03-23-30-059","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-057716757052/byoc-cifar10/code/sourcedir.tar.gz","module_name":"cifar10_keras_sm_tf2","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"cifar10_keras_sm_tf2.py"}
# SM_USER_ARGS=["--epochs","5","--model_dir","./logs"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_DIR=./logs
# SM_HP_EPOCHS=5
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 cifar10_keras_sm_tf2.py --epochs 5 --model_dir ./logs
#
#
# 2021-02-27 03:28:23.152010: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-02-27 03:28:23.305070: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-27 03:28:23.306187: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8755GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2021-02-27 03:28:23.309327: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-27 03:28:23.394740: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-02-27 03:28:23.440358: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-02-27 03:28:23.452072: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-02-27 03:28:23.536956: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-02-27 03:28:23.545959: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-02-27 03:28:23.700341: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-02-27 03:28:23.700557: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-27 03:28:23.701516: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-27 03:28:23.702301: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-02-27 03:28:23.703569: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-02-27 03:28:23.719786: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300100000 Hz
# 2021-02-27 03:28:23.720189: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f5eb8000b20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-02-27 03:28:23.720224: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-02-27 03:28:23.975830: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-27 03:28:23.976748: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x61fc110 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-02-27 03:28:23.976778: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2021-02-27 03:28:23.978777: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-27 03:28:23.979585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8755GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2021-02-27 03:28:23.979659: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-27 03:28:23.979692: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-02-27 03:28:23.979720: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-02-27 03:28:23.979747: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-02-27 03:28:23.979783: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-02-27 03:28:23.979810: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-02-27 03:28:23.979840: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-02-27 03:28:23.979936: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-27 03:28:23.980765: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-27 03:28:23.981512: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2021-02-27 03:28:23.982743: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-02